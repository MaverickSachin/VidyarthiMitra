# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)
pd.options.display.float_format = '{:.7f}'.format

# %%
df = pd.read_excel("Input - FE Cut-offs 2021.xlsx")

df_obj = df.select_dtypes(['object'])
df[df_obj.columns] = df_obj.apply(lambda x: x.str.strip())

df.loc[df['Merit'].isnull(), 'Merit'] = 0
df.loc[df['Total Intake'].isnull(), 'Total Intake'] = 0

df['Merit'] = df['Merit'].astype('int64')
df['Total Intake'] = df['Total Intake'].astype('int64')

df1 = df.copy(deep=True)

# %%
df.head()
# Out:
#    Merit    MHT-CET Gender Candidate Category SeatType                Status  \
# 0   3223 97.6728668      M                 SC   GOPENS  GovernmentAutonomous
# 1   3495 97.4852721      M                SBC   GOPENS  GovernmentAutonomous
# 2   7272 94.9063923      M                OBC   GOPENS  GovernmentAutonomous
# 3   7648 94.6234735      F                OBC   LOPENS  GovernmentAutonomous
# 4   8153 94.3233326      M        NT 1 (NT-B)   GOPENS  GovernmentAutonomous
#
#    JEE(Main) Paper I Score  University name  \
# 0                      NaN              NaN
# 1                      NaN              NaN
# 2                      NaN              NaN
# 3                      NaN              NaN
# 4                      NaN              NaN
#
#                                  College Code & Name Course Code  \
# 0  1002   Government College of Engineering, Amra...   100219110
# 1  1002   Government College of Engineering, Amra...   100219110
# 2  1002   Government College of Engineering, Amra...   100219110
# 3  1002   Government College of Engineering, Amra...   100219110
# 4  1002   Government College of Engineering, Amra...   100219110
#
#           Course name          CAP  Institute Code  \
# 0   Civil Engineering  CAP Round-I            1002
# 1   Civil Engineering  CAP Round-I            1002
# 2   Civil Engineering  CAP Round-I            1002
# 3   Civil Engineering  CAP Round-I            1002
# 4   Civil Engineering  CAP Round-I            1002
#
#                                 Institute Name  \
# 0  Government College of Engineering, Amravati
# 1  Government College of Engineering, Amravati
# 2  Government College of Engineering, Amravati
# 3  Government College of Engineering, Amravati
# 4  Government College of Engineering, Amravati
#
#                         Institute Address  District    Region    Status.1  \
# 0  VMV Road, Near Kathora Naka,  Amravati  Amravati  Amravati  Government
# 1  VMV Road, Near Kathora Naka,  Amravati  Amravati  Amravati  Government
# 2  VMV Road, Near Kathora Naka,  Amravati  Amravati  Amravati  Government
# 3  VMV Road, Near Kathora Naka,  Amravati  Amravati  Amravati  Government
# 4  VMV Road, Near Kathora Naka,  Amravati  Amravati  Amravati  Government
#
#   Minority Status Choice Code        Course Name  \
# 0    Non-Minority   100219110  Civil Engineering
# 1    Non-Minority   100219110  Civil Engineering
# 2    Non-Minority   100219110  Civil Engineering
# 3    Non-Minority   100219110  Civil Engineering
# 4    Non-Minority   100219110  Civil Engineering
#
#                             University    Status.2 Autonomy Status  \
# 0  Sant Gadge Baba Amravati University  Government      Autonomous
# 1  Sant Gadge Baba Amravati University  Government      Autonomous
# 2  Sant Gadge Baba Amravati University  Government      Autonomous
# 3  Sant Gadge Baba Amravati University  Government      Autonomous
# 4  Sant Gadge Baba Amravati University  Government      Autonomous
#
#   Minority Status.1          Shift Accreditation      Gender.1  Total Intake  \
# 0      Non-Minority  General Shift             -  Co-Education            60
# 1      Non-Minority  General Shift             -  Co-Education            60
# 2      Non-Minority  General Shift             -  Co-Education            60
# 3      Non-Minority  General Shift             -  Co-Education            60
# 4      Non-Minority  General Shift             -  Co-Education            60
#
#   CAP Round
# 0     CAP I
# 1     CAP I
# 2     CAP I
# 3     CAP I
# 4     CAP I

# %%
cap_rounds = df['CAP'].unique().tolist()
institude_codes = df['Institute Code'].unique().tolist()
course_names = df['Course name'].unique().tolist()
categories = df['Candidate Category'].unique().tolist()

# %%
df2 = df1.loc[starting_points[4]+2:end_points[4]-1]

college_names = df2["Unnamed: 1"].tolist()

# dropping the first column from the dataframe
df2.drop('Unnamed: 1', axis=1, inplace=True)
df2.drop('Unnamed: 2', axis=1, inplace=True)
df2.reset_index(inplace = True)
df2.drop('index', axis=1, inplace=True)
df2, df2.columns = df2[1:] , df2.iloc[0]
df2.replace(np.NaN, 'N/A', inplace=True)
df2 = df2.loc[:, df2.columns.notnull()]
# Out:
# s:\freelancing\vidyarthimitra\venv\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df = pd.read_excel("Input - NEET Opening Closing 2020.xlsx")

starting_points = df.loc[df['Unnamed: 0'].str.contains('Admissions', na=False), 'Unnamed: 0'].index.tolist()
end_points = df.loc[df['Unnamed: 0'].str.contains('LEGEND', na=False), 'Unnamed: 0'].index.tolist()

categories = ['SC', 'ST', 'VJ', 'NT1', 'NT2', 'NT3', 'OBC', 'EWS', 'OPEN', 'D1', 'D2', 'D3', 'PH', 'MKB', 'NRI']
columns = ['Code', 'College Name', 'Category', 'S - AIR', 'M - Marks Obtained', 'Course', 'College Type']

final = pd.DataFrame(columns=columns)

df1 = df.copy(deep=True)

# dropping the first column from the dataframe
df1.drop('Unnamed: 0', axis=1, inplace=True)

for start, end in zip(starting_points, end_points):
    
    df2 = df1.loc[start+2:end-1]
    
    # Name of the course and type of the college
    course_college_type = df1.iloc[start + 1, :].dropna()[0].split("Quotawise List of Last Admitted Candidates In ")[1:][0].strip()

    split_by = '  ' if '  ' in course_college_type else ' '
    course_college_type = course_college_type.split(split_by)
    course = course_college_type[0]
    college_type = course_college_type[1] if len(course_college_type) >= 2 else "N/A"

    college_names = df2["Unnamed: 1"].tolist()[1:]

    # dropping the first column from the dataframe
    df2.drop('Unnamed: 1', axis=1, inplace=True)
    df2.drop('Unnamed: 2', axis=1, inplace=True)
    df2.reset_index(drop=True, inplace = True)
    
    df2, df2.columns = df2[1:] , df2.iloc[0]
    df2.replace(np.NaN, 'N/A', inplace=True)
    df2 = df2.loc[:, df2.columns.notnull()]
    
    df2.reset_index(drop=True, inplace = True)
    
    missing_categories = list(set(categories) - set(df2.columns.tolist()))
    
    for category in missing_categories:
        df2[category] = 'N/A'
    
    df2 = df2[categories]
    
    output = []
    for i in range(0, len(college_names), 2):
        first_part = college_names[i]
        if first_part[-1] == ":":
            first_part = first_part[:-4]

        if pd.isna(college_names[i + 1]):
            second_part = ""
        else:
            second_part = college_names[i+1]
            if second_part[-1] == ":":
                second_part = second_part[:-4]

        output.append(first_part.strip() + ' ' + second_part.strip())

    i = 0
    for item in output:
        if item.split(" ")[0].isnumeric() and item.split(" ")[1].isnumeric():
            college_code = item.split(" ")[1]
            college_name = "".join(item.split(" ")[2:])
        else:
            college_code = item.split(" ")[0]
            college_name = " ".join(item.split(" ")[1:])

        college_code = [college_code] * 15
        college_name = [college_name] * 15
        
        course = [course_college_type[0]] * 15
        college_type = [course_college_type[1] if len(course_college_type) >= 2 else "N/A"] * 15

        # rankings AIR
        rankings = df2.iloc[i, :].tolist()

        # marks obtained 
        marks = df2.iloc[i+1, :].tolist()
        i += 2
        
        new_df = pd.DataFrame(list(zip(college_code, college_name, categories, rankings, marks, course, college_type)), columns=columns)
        final = pd.concat([final, new_df], axis=0)
# Out:
# s:\freelancing\vidyarthimitra\venv\lib\site-packages\pandas\core\frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
final.reset_index(drop=True, inplace=True)
final.head(1000)
# Out:
#       Code                    College Name Category S - AIR  \
# 0    01101                    GMC, MUMBAI        SC   47384
# 1    01101                    GMC, MUMBAI        ST  180913
# 2    01101                    GMC, MUMBAI        VJ   22048
# 3    01101                    GMC, MUMBAI       NT1   32096
# 4    01101                    GMC, MUMBAI       NT2   12268
# 5    01101                    GMC, MUMBAI       NT3    7007
# 6    01101                    GMC, MUMBAI       OBC   12081
# 7    01101                    GMC, MUMBAI       EWS   13670
# 8    01101                    GMC, MUMBAI      OPEN    8971
# 9    01101                    GMC, MUMBAI        D1   20470
# 10   01101                    GMC, MUMBAI        D2    4111
# 11   01101                    GMC, MUMBAI        D3    9448
# 12   01101                    GMC, MUMBAI        PH  624419
# 13   01101                    GMC, MUMBAI       MKB   33135
# 14   01101                    GMC, MUMBAI       NRI     N/A
# 15   01102               Tilak MC, MUMBAI        SC   60922
# 16   01102               Tilak MC, MUMBAI        ST  261328
# 17   01102               Tilak MC, MUMBAI        VJ   36398
# 18   01102               Tilak MC, MUMBAI       NT1   39169
# 19   01102               Tilak MC, MUMBAI       NT2   22834
# 20   01102               Tilak MC, MUMBAI       NT3   11428
# 21   01102               Tilak MC, MUMBAI       OBC   14492
# 22   01102               Tilak MC, MUMBAI       EWS   15409
# 23   01102               Tilak MC, MUMBAI      OPEN    8305
# 24   01102               Tilak MC, MUMBAI        D1   30897
# 25   01102               Tilak MC, MUMBAI        D2   14019
# 26   01102               Tilak MC, MUMBAI        D3   22912
# 27   01102               Tilak MC, MUMBAI        PH  726401
# 28   01102               Tilak MC, MUMBAI       MKB     N/A
# 29   01102               Tilak MC, MUMBAI       NRI     N/A
# 30   01103                   GSMC, MUMBAI        SC   29063
# 31   01103                   GSMC, MUMBAI        ST  147045
# 32   01103                   GSMC, MUMBAI        VJ    7264
# 33   01103                   GSMC, MUMBAI       NT1   26937
# 34   01103                   GSMC, MUMBAI       NT2    8618
# 35   01103                   GSMC, MUMBAI       NT3    3798
# 36   01103                   GSMC, MUMBAI       OBC    5545
# 37   01103                   GSMC, MUMBAI       EWS    4941
# 38   01103                   GSMC, MUMBAI      OPEN    2669
# 39   01103                   GSMC, MUMBAI        D1    3971
# 40   01103                   GSMC, MUMBAI        D2    5745
# 41   01103                   GSMC, MUMBAI        D3    8296
# 42   01103                   GSMC, MUMBAI        PH  620669
# 43   01103                   GSMC, MUMBAI       MKB     N/A
# 44   01103                   GSMC, MUMBAI       NRI     N/A
# 45   01104                Nair MC, MUMBAI        SC   56795
# 46   01104                Nair MC, MUMBAI        ST  253139
# 47   01104                Nair MC, MUMBAI        VJ   17825
# 48   01104                Nair MC, MUMBAI       NT1   42232
# 49   01104                Nair MC, MUMBAI       NT2   16036
# 50   01104                Nair MC, MUMBAI       NT3   10666
# 51   01104                Nair MC, MUMBAI       OBC    9506
# 52   01104                Nair MC, MUMBAI       EWS   12792
# 53   01104                Nair MC, MUMBAI      OPEN    8609
# 54   01104                Nair MC, MUMBAI        D1   27720
# 55   01104                Nair MC, MUMBAI        D2    9051
# 56   01104                Nair MC, MUMBAI        D3   18551
# 57   01104                Nair MC, MUMBAI        PH  532883
# 58   01104                Nair MC, MUMBAI       MKB     N/A
# 59   01104                Nair MC, MUMBAI       NRI     N/A
# 60   01109              RGMC KALVA, THANE        SC   72172
# 61   01109              RGMC KALVA, THANE        ST  269328
# 62   01109              RGMC KALVA, THANE        VJ   43343
# 63   01109              RGMC KALVA, THANE       NT1   67581
# 64   01109              RGMC KALVA, THANE       NT2   37511
# 65   01109              RGMC KALVA, THANE       NT3   16730
# 66   01109              RGMC KALVA, THANE       OBC   21200
# 67   01109              RGMC KALVA, THANE       EWS   20828
# 68   01109              RGMC KALVA, THANE      OPEN   12484
# 69   01109              RGMC KALVA, THANE        D1   37711
# 70   01109              RGMC KALVA, THANE        D2   23751
# 71   01109              RGMC KALVA, THANE        D3   38054
# 72   01109              RGMC KALVA, THANE        PH  731222
# 73   01109              RGMC KALVA, THANE       MKB     N/A
# 74   01109              RGMC KALVA, THANE       NRI     N/A
# 75   01110                     BJMC, PUNE        SC   55684
# 76   01110                     BJMC, PUNE        ST  140466
# 77   01110                     BJMC, PUNE        VJ   34772
# 78   01110                     BJMC, PUNE       NT1   51451
# 79   01110                     BJMC, PUNE       NT2   21820
# 80   01110                     BJMC, PUNE       NT3    9881
# 81   01110                     BJMC, PUNE       OBC   12789
# 82   01110                     BJMC, PUNE       EWS   14474
# 83   01110                     BJMC, PUNE      OPEN    7296
# 84   01110                     BJMC, PUNE        D1   23049
# 85   01110                     BJMC, PUNE        D2   12775
# 86   01110                     BJMC, PUNE        D3   11206
# 87   01110                     BJMC, PUNE        PH  522516
# 88   01110                     BJMC, PUNE       MKB   23070
# 89   01110                     BJMC, PUNE       NRI     N/A
# 90   01114                V M MC, SOLAPUR        SC   84587
# 91   01114                V M MC, SOLAPUR        ST  238220
# 92   01114                V M MC, SOLAPUR        VJ   63566
# 93   01114                V M MC, SOLAPUR       NT1   82390
# 94   01114                V M MC, SOLAPUR       NT2   37430
# 95   01114                V M MC, SOLAPUR       NT3   21601
# 96   01114                V M MC, SOLAPUR       OBC   25850
# 97   01114                V M MC, SOLAPUR       EWS   26482
# 98   01114                V M MC, SOLAPUR      OPEN   20361
# 99   01114                V M MC, SOLAPUR        D1   50754
# 100  01114                V M MC, SOLAPUR        D2   27482
# 101  01114                V M MC, SOLAPUR        D3   24549
# 102  01114                V M MC, SOLAPUR        PH  627977
# 103  01114                V M MC, SOLAPUR       MKB   77446
# 104  01114                V M MC, SOLAPUR       NRI     N/A
# 105  01115                     GMC, MIRAJ        SC   92140
# 106  01115                     GMC, MIRAJ        ST  240855
# 107  01115                     GMC, MIRAJ        VJ   66194
# 108  01115                     GMC, MIRAJ       NT1   77389
# 109  01115                     GMC, MIRAJ       NT2   34272
# 110  01115                     GMC, MIRAJ       NT3   24844
# 111  01115                     GMC, MIRAJ       OBC   29693
# 112  01115                     GMC, MIRAJ       EWS   27311
# 113  01115                     GMC, MIRAJ      OPEN   21929
# 114  01115                     GMC, MIRAJ        D1   47798
# 115  01115                     GMC, MIRAJ        D2   40536
# 116  01115                     GMC, MIRAJ        D3   64637
# 117  01115                     GMC, MIRAJ        PH  774731
# 118  01115                     GMC, MIRAJ       MKB   80046
# 119  01115                     GMC, MIRAJ       NRI     N/A
# 120  01119               B HIRE MC, DHULE        SC  100221
# 121  01119               B HIRE MC, DHULE        ST  280419
# 122  01119               B HIRE MC, DHULE        VJ   70588
# 123  01119               B HIRE MC, DHULE       NT1   87916
# 124  01119               B HIRE MC, DHULE       NT2   43407
# 125  01119               B HIRE MC, DHULE       NT3   36341
# 126  01119               B HIRE MC, DHULE       OBC   35122
# 127  01119               B HIRE MC, DHULE       EWS   34764
# 128  01119               B HIRE MC, DHULE      OPEN   30675
# 129  01119               B HIRE MC, DHULE        D1   59671
# 130  01119               B HIRE MC, DHULE        D2   52841
# 131  01119               B HIRE MC, DHULE        D3   72813
# 132  01119               B HIRE MC, DHULE        PH  794117
# 133  01119               B HIRE MC, DHULE       MKB     N/A
# 134  01119               B HIRE MC, DHULE       NRI     N/A
# 135  01132                  GMC, KOLHAPUR        SC   91795
# 136  01132                  GMC, KOLHAPUR        ST  269799
# 137  01132                  GMC, KOLHAPUR        VJ   63353
# 138  01132                  GMC, KOLHAPUR       NT1   86689
# 139  01132                  GMC, KOLHAPUR       NT2   40125
# 140  01132                  GMC, KOLHAPUR       NT3   28002
# 141  01132                  GMC, KOLHAPUR       OBC   30276
# 142  01132                  GMC, KOLHAPUR       EWS     N/A
# 143  01132                  GMC, KOLHAPUR      OPEN   23483
# 144  01132                  GMC, KOLHAPUR        D1   50260
# 145  01132                  GMC, KOLHAPUR        D2   40697
# 146  01132                  GMC, KOLHAPUR        D3   39087
# 147  01132                  GMC, KOLHAPUR        PH  700745
# 148  01132                  GMC, KOLHAPUR       MKB   56693
# 149  01132                  GMC, KOLHAPUR       NRI     N/A
# 150  01140   HBT & COOPER MC, JUHU, MUMBAI       SC   66493
# 151  01140   HBT & COOPER MC, JUHU, MUMBAI       ST  238985
# 152  01140   HBT & COOPER MC, JUHU, MUMBAI       VJ   42156
# 153  01140   HBT & COOPER MC, JUHU, MUMBAI      NT1   56817
# 154  01140   HBT & COOPER MC, JUHU, MUMBAI      NT2   25830
# 155  01140   HBT & COOPER MC, JUHU, MUMBAI      NT3   13545
# 156  01140   HBT & COOPER MC, JUHU, MUMBAI      OBC   17736
# 157  01140   HBT & COOPER MC, JUHU, MUMBAI      EWS   18834
# 158  01140   HBT & COOPER MC, JUHU, MUMBAI     OPEN   10861
# 159  01140   HBT & COOPER MC, JUHU, MUMBAI       D1   38125
# 160  01140   HBT & COOPER MC, JUHU, MUMBAI       D2   10047
# 161  01140   HBT & COOPER MC, JUHU, MUMBAI       D3   25958
# 162  01140   HBT & COOPER MC, JUHU, MUMBAI       PH  703864
# 163  01140   HBT & COOPER MC, JUHU, MUMBAI      MKB     N/A
# 164  01140   HBT & COOPER MC, JUHU, MUMBAI      NRI     N/A
# 165  01149                   GMC, JALGAON        SC  101954
# 166  01149                   GMC, JALGAON        ST  280290
# 167  01149                   GMC, JALGAON        VJ   71219
# 168  01149                   GMC, JALGAON       NT1   91384
# 169  01149                   GMC, JALGAON       NT2   46023
# 170  01149                   GMC, JALGAON       NT3   35914
# 171  01149                   GMC, JALGAON       OBC   36330
# 172  01149                   GMC, JALGAON       EWS   36073
# 173  01149                   GMC, JALGAON      OPEN   32363
# 174  01149                   GMC, JALGAON        D1   69468
# 175  01149                   GMC, JALGAON        D2   54543
# 176  01149                   GMC, JALGAON        D3   42262
# 177  01149                   GMC, JALGAON        PH  743676
# 178  01149                   GMC, JALGAON       MKB     N/A
# 179  01149                   GMC, JALGAON       NRI     N/A
# 180  01150                  GMC, BARAMATI        SC   91605
# 181  01150                  GMC, BARAMATI        ST  255818
# 182  01150                  GMC, BARAMATI        VJ   58641
# 183  01150                  GMC, BARAMATI       NT1   71176
# 184  01150                  GMC, BARAMATI       NT2   37392
# 185  01150                  GMC, BARAMATI       NT3   29144
# 186  01150                  GMC, BARAMATI       OBC   30811
# 187  01150                  GMC, BARAMATI       EWS     N/A
# 188  01150                  GMC, BARAMATI      OPEN   23597
# 189  01150                  GMC, BARAMATI        D1   55716
# 190  01150                  GMC, BARAMATI        D2   65487
# 191  01150                  GMC, BARAMATI        D3   74645
# 192  01150                  GMC, BARAMATI        PH  740871
# 193  01150                  GMC, BARAMATI       MKB     N/A
# 194  01150                  GMC, BARAMATI       NRI     N/A
# 195  01151                 GMC, NANDURBAR        SC  106288
# 196  01151                 GMC, NANDURBAR        ST  281689
# 197  01151                 GMC, NANDURBAR        VJ   69919
# 198  01151                 GMC, NANDURBAR       NT1   96934
# 199  01151                 GMC, NANDURBAR       NT2   46780
# 200  01151                 GMC, NANDURBAR       NT3   37312
# 201  01151                 GMC, NANDURBAR       OBC   37747
# 202  01151                 GMC, NANDURBAR       EWS     N/A
# 203  01151                 GMC, NANDURBAR      OPEN   35547
# 204  01151                 GMC, NANDURBAR        D1   70916
# 205  01151                 GMC, NANDURBAR        D2   64634
# 206  01151                 GMC, NANDURBAR        D3   50007
# 207  01151                 GMC, NANDURBAR        PH  103198
# 208  01151                 GMC, NANDURBAR       MKB     N/A
# 209  01151                 GMC, NANDURBAR       NRI     N/A
# 210  01221                    GMC, NAGPUR        SC   49810
# 211  01221                    GMC, NAGPUR        ST  161267
# 212  01221                    GMC, NAGPUR        VJ   43755
# 213  01221                    GMC, NAGPUR       NT1   34052
# 214  01221                    GMC, NAGPUR       NT2   32305
# 215  01221                    GMC, NAGPUR       NT3   16311
# 216  01221                    GMC, NAGPUR       OBC   16152
# 217  01221                    GMC, NAGPUR       EWS   21001
# 218  01221                    GMC, NAGPUR      OPEN   13731
# 219  01221                    GMC, NAGPUR        D1   42295
# 220  01221                    GMC, NAGPUR        D2   14681
# 221  01221                    GMC, NAGPUR        D3   38640
# 222  01221                    GMC, NAGPUR        PH  670022
# 223  01221                    GMC, NAGPUR       MKB     N/A
# 224  01221                    GMC, NAGPUR       NRI     N/A
# 225  01222                   IGMC, NAGPUR        SC   60786
# 226  01222                   IGMC, NAGPUR        ST  203085
# 227  01222                   IGMC, NAGPUR        VJ   47367
# 228  01222                   IGMC, NAGPUR       NT1   53233
# 229  01222                   IGMC, NAGPUR       NT2   37245
# 230  01222                   IGMC, NAGPUR       NT3   22860
# 231  01222                   IGMC, NAGPUR       OBC   19956
# 232  01222                   IGMC, NAGPUR       EWS   27056
# 233  01222                   IGMC, NAGPUR      OPEN   19307
# 234  01222                   IGMC, NAGPUR        D1   45052
# 235  01222                   IGMC, NAGPUR        D2   17705
# 236  01222                   IGMC, NAGPUR        D3   76068
# 237  01222                   IGMC, NAGPUR        PH  691224
# 238  01222                   IGMC, NAGPUR       MKB     N/A
# 239  01222                   IGMC, NAGPUR       NRI     N/A
# 240  01226                  VNMC, YEOTMAL        SC   93092
# 241  01226                  VNMC, YEOTMAL        ST  267396
# 242  01226                  VNMC, YEOTMAL        VJ   67621
# 243  01226                  VNMC, YEOTMAL       NT1   82274
# 244  01226                  VNMC, YEOTMAL       NT2   44844
# 245  01226                  VNMC, YEOTMAL       NT3   35861
# 246  01226                  VNMC, YEOTMAL       OBC   32223
# 247  01226                  VNMC, YEOTMAL       EWS   35096
# 248  01226                  VNMC, YEOTMAL      OPEN   31209
# 249  01226                  VNMC, YEOTMAL        D1   64589
# 250  01226                  VNMC, YEOTMAL        D2   41953
# 251  01226                  VNMC, YEOTMAL        D3   60607
# 252  01226                  VNMC, YEOTMAL        PH  683404
# 253  01226                  VNMC, YEOTMAL       MKB     N/A
# 254  01226                  VNMC, YEOTMAL       NRI     N/A
# 255  01234                     GMC AKOLA,        SC   92227
# 256  01234                     GMC AKOLA,        ST  266876
# 257  01234                     GMC AKOLA,        VJ   64638
# 258  01234                     GMC AKOLA,       NT1   84244
# 259  01234                     GMC AKOLA,       NT2   44628
# 260  01234                     GMC AKOLA,       NT3   28463
# 261  01234                     GMC AKOLA,       OBC   28253
# 262  01234                     GMC AKOLA,       EWS   33975
# 263  01234                     GMC AKOLA,      OPEN   29876
# 264  01234                     GMC AKOLA,        D1   63838
# 265  01234                     GMC AKOLA,        D2   45563
# 266  01234                     GMC AKOLA,        D3   81426
# 267  01234                     GMC AKOLA,        PH  656751
# 268  01234                     GMC AKOLA,       MKB   85671
# 269  01234                     GMC AKOLA,       NRI     N/A
# 270  01241               CGMC, CHANDRAPUR        SC   98013
# 271  01241               CGMC, CHANDRAPUR        ST  268425
# 272  01241               CGMC, CHANDRAPUR        VJ   69374
# 273  01241               CGMC, CHANDRAPUR       NT1   87348
# 274  01241               CGMC, CHANDRAPUR       NT2   46897
# 275  01241               CGMC, CHANDRAPUR       NT3   36360
# 276  01241               CGMC, CHANDRAPUR       OBC   35386
# 277  01241               CGMC, CHANDRAPUR       EWS   37015
# 278  01241               CGMC, CHANDRAPUR      OPEN   33495
# 279  01241               CGMC, CHANDRAPUR        D1   68866
# 280  01241               CGMC, CHANDRAPUR        D2   55803
# 281  01241               CGMC, CHANDRAPUR        D3   82772
# 282  01241               CGMC, CHANDRAPUR        PH  807072
# 283  01241               CGMC, CHANDRAPUR       MKB     N/A
# 284  01241               CGMC, CHANDRAPUR       NRI     N/A
# 285  01242                   GGMC, GONDIA        SC  103247
# 286  01242                   GGMC, GONDIA        ST  280677
# 287  01242                   GGMC, GONDIA        VJ   69446
# 288  01242                   GGMC, GONDIA       NT1   93651
# 289  01242                   GGMC, GONDIA       NT2   47139
# 290  01242                   GGMC, GONDIA       NT3   37508
# 291  01242                   GGMC, GONDIA       OBC   36827
# 292  01242                   GGMC, GONDIA       EWS   37208
# 293  01242                   GGMC, GONDIA      OPEN   35097
# 294  01242                   GGMC, GONDIA        D1   70307
# 295  01242                   GGMC, GONDIA        D2   66007
# 296  01242                   GGMC, GONDIA        D3   84774
# 297  01242                   GGMC, GONDIA        PH  817179
# 298  01242                   GGMC, GONDIA       MKB     N/A
# 299  01242                   GGMC, GONDIA       NRI     N/A
# 300  01248       MGIMS MC, SEVAGRAM,WARDHA       SC   91463
# 301  01248       MGIMS MC, SEVAGRAM,WARDHA       ST  242366
# 302  01248       MGIMS MC, SEVAGRAM,WARDHA       VJ   61208
# 303  01248       MGIMS MC, SEVAGRAM,WARDHA      NT1   82960
# 304  01248       MGIMS MC, SEVAGRAM,WARDHA      NT2   42326
# 305  01248       MGIMS MC, SEVAGRAM,WARDHA      NT3   34212
# 306  01248       MGIMS MC, SEVAGRAM,WARDHA      OBC   30914
# 307  01248       MGIMS MC, SEVAGRAM,WARDHA      EWS     N/A
# 308  01248       MGIMS MC, SEVAGRAM,WARDHA     OPEN   23898
# 309  01248       MGIMS MC, SEVAGRAM,WARDHA       D1     N/A
# 310  01248       MGIMS MC, SEVAGRAM,WARDHA       D2     N/A
# 311  01248       MGIMS MC, SEVAGRAM,WARDHA       D3     N/A
# 312  01248       MGIMS MC, SEVAGRAM,WARDHA       PH   27574
# 313  01248       MGIMS MC, SEVAGRAM,WARDHA      MKB     N/A
# 314  01248       MGIMS MC, SEVAGRAM,WARDHA      NRI     N/A
# 315  01327                GMC, AURANGABAD        SC   72509
# 316  01327                GMC, AURANGABAD        ST  262891
# 317  01327                GMC, AURANGABAD        VJ   41958
# 318  01327                GMC, AURANGABAD       NT1   65944
# 319  01327                GMC, AURANGABAD       NT2   27275
# 320  01327                GMC, AURANGABAD       NT3   15845
# 321  01327                GMC, AURANGABAD       OBC   20506
# 322  01327                GMC, AURANGABAD       EWS   22174
# 323  01327                GMC, AURANGABAD      OPEN   14738
# 324  01327                GMC, AURANGABAD        D1   43659
# 325  01327                GMC, AURANGABAD        D2   41498
# 326  01327                GMC, AURANGABAD        D3   20168
# 327  01327                GMC, AURANGABAD        PH  708246
# 328  01327                GMC, AURANGABAD       MKB   33307
# 329  01327                GMC, AURANGABAD       NRI     N/A
# 330  01328                    GMC, NANDED        SC   90250
# 331  01328                    GMC, NANDED        ST  249482
# 332  01328                    GMC, NANDED        VJ   58747
# 333  01328                    GMC, NANDED       NT1   63241
# 334  01328                    GMC, NANDED       NT2   40961
# 335  01328                    GMC, NANDED       NT3   32261
# 336  01328                    GMC, NANDED       OBC   31266
# 337  01328                    GMC, NANDED       EWS   29857
# 338  01328                    GMC, NANDED      OPEN   25368
# 339  01328                    GMC, NANDED        D1   56409
# 340  01328                    GMC, NANDED        D2   41793
# 341  01328                    GMC, NANDED        D3   44409
# 342  01328                    GMC, NANDED        PH  805573
# 343  01328                    GMC, NANDED       MKB     N/A
# 344  01328                    GMC, NANDED       NRI     N/A
# 345  01329             SRTR MC, AMBAJOGAI        SC   96553
# 346  01329             SRTR MC, AMBAJOGAI        ST  264005
# 347  01329             SRTR MC, AMBAJOGAI        VJ   58038
# 348  01329             SRTR MC, AMBAJOGAI       NT1   89565
# 349  01329             SRTR MC, AMBAJOGAI       NT2   41406
# 350  01329             SRTR MC, AMBAJOGAI       NT3   32070
# 351  01329             SRTR MC, AMBAJOGAI       OBC   34491
# 352  01329             SRTR MC, AMBAJOGAI       EWS   32642
# 353  01329             SRTR MC, AMBAJOGAI      OPEN   30095
# 354  01329             SRTR MC, AMBAJOGAI        D1   65302
# 355  01329             SRTR MC, AMBAJOGAI        D2   51457
# 356  01329             SRTR MC, AMBAJOGAI        D3   60974
# 357  01329             SRTR MC, AMBAJOGAI        PH  679346
# 358  01329             SRTR MC, AMBAJOGAI       MKB     N/A
# 359  01329             SRTR MC, AMBAJOGAI       NRI     N/A
# 360  01333                     GMC LATUR,        SC   94767
# 361  01333                     GMC LATUR,        ST  252981
# 362  01333                     GMC LATUR,        VJ   65011
# 363  01333                     GMC LATUR,       NT1   78994
# 364  01333                     GMC LATUR,       NT2   37621
# 365  01333                     GMC LATUR,       NT3   32427
# 366  01333                     GMC LATUR,       OBC   33071
# 367  01333                     GMC LATUR,       EWS     N/A
# 368  01333                     GMC LATUR,      OPEN   28262
# 369  01333                     GMC LATUR,        D1   60309
# 370  01333                     GMC LATUR,        D2   51823
# 371  01333                     GMC LATUR,        D3   64733
# 372  01333                     GMC LATUR,        PH  643828
# 373  01333                     GMC LATUR,       MKB   88030
# 374  01333                     GMC LATUR,       NRI     N/A
# 375  01105          K J Somaiya MC, MUMBAI       SC   93116
# 376  01105          K J Somaiya MC, MUMBAI       ST  283139
# 377  01105          K J Somaiya MC, MUMBAI       VJ   74891
# 378  01105          K J Somaiya MC, MUMBAI      NT1   89609
# 379  01105          K J Somaiya MC, MUMBAI      NT2   48269
# 380  01105          K J Somaiya MC, MUMBAI      NT3     N/A
# 381  01105          K J Somaiya MC, MUMBAI      OBC   43710
# 382  01105          K J Somaiya MC, MUMBAI      EWS     N/A
# 383  01105          K J Somaiya MC, MUMBAI     OPEN   37244
# 384  01105          K J Somaiya MC, MUMBAI       D1     N/A
# 385  01105          K J Somaiya MC, MUMBAI       D2     N/A
# 386  01105          K J Somaiya MC, MUMBAI       D3     N/A
# 387  01105          K J Somaiya MC, MUMBAI       PH     N/A
# 388  01105          K J Somaiya MC, MUMBAI      MKB     N/A
# 389  01105          K J Somaiya MC, MUMBAI      NRI  239080
# 390  01108     Terna MC NERUL, NAVI MUMBAI       SC  103853
# 391  01108     Terna MC NERUL, NAVI MUMBAI       ST  280073
# 392  01108     Terna MC NERUL, NAVI MUMBAI       VJ   75682
# 393  01108     Terna MC NERUL, NAVI MUMBAI      NT1   93998
# 394  01108     Terna MC NERUL, NAVI MUMBAI      NT2   48129
# 395  01108     Terna MC NERUL, NAVI MUMBAI      NT3   39356
# 396  01108     Terna MC NERUL, NAVI MUMBAI      OBC   40762
# 397  01108     Terna MC NERUL, NAVI MUMBAI      EWS     N/A
# 398  01108     Terna MC NERUL, NAVI MUMBAI     OPEN   39537
# 399  01108     Terna MC NERUL, NAVI MUMBAI       D1     N/A
# 400  01108     Terna MC NERUL, NAVI MUMBAI       D2     N/A
# 401  01108     Terna MC NERUL, NAVI MUMBAI       D3     N/A
# 402  01108     Terna MC NERUL, NAVI MUMBAI       PH     N/A
# 403  01108     Terna MC NERUL, NAVI MUMBAI      MKB     N/A
# 404  01108     Terna MC NERUL, NAVI MUMBAI      NRI  630217
# 405  01112         MIMER MC, TALEGAON PUNE       SC  105678
# 406  01112         MIMER MC, TALEGAON PUNE       ST  282953
# 407  01112         MIMER MC, TALEGAON PUNE       VJ   80510
# 408  01112         MIMER MC, TALEGAON PUNE      NT1  108721
# 409  01112         MIMER MC, TALEGAON PUNE      NT2   53222
# 410  01112         MIMER MC, TALEGAON PUNE      NT3   49657
# 411  01112         MIMER MC, TALEGAON PUNE      OBC   56828
# 412  01112         MIMER MC, TALEGAON PUNE      EWS     N/A
# 413  01112         MIMER MC, TALEGAON PUNE     OPEN   55391
# 414  01112         MIMER MC, TALEGAON PUNE       D1     N/A
# 415  01112         MIMER MC, TALEGAON PUNE       D2     N/A
# 416  01112         MIMER MC, TALEGAON PUNE       D3     N/A
# 417  01112         MIMER MC, TALEGAON PUNE       PH     N/A
# 418  01112         MIMER MC, TALEGAON PUNE      MKB     N/A
# 419  01112         MIMER MC, TALEGAON PUNE      NRI  701380
# 420  01118              V PAWAR MC, NASIK        SC  106691
# 421  01118              V PAWAR MC, NASIK        ST  280080
# 422  01118              V PAWAR MC, NASIK        VJ   77284
# 423  01118              V PAWAR MC, NASIK       NT1  115947
# 424  01118              V PAWAR MC, NASIK       NT2   48561
# 425  01118              V PAWAR MC, NASIK       NT3   44652
# 426  01118              V PAWAR MC, NASIK       OBC   44708
# 427  01118              V PAWAR MC, NASIK       EWS     N/A
# 428  01118              V PAWAR MC, NASIK      OPEN   44878
# 429  01118              V PAWAR MC, NASIK        D1     N/A
# 430  01118              V PAWAR MC, NASIK        D2     N/A
# 431  01118              V PAWAR MC, NASIK        D3     N/A
# 432  01118              V PAWAR MC, NASIK        PH     N/A
# 433  01118              V PAWAR MC, NASIK       MKB     N/A
# 434  01118              V PAWAR MC, NASIK       NRI  647359
# 435  01120                 ACPM MC, DHULE        SC  112294
# 436  01120                 ACPM MC, DHULE        ST  290553
# 437  01120                 ACPM MC, DHULE        VJ   78570
# 438  01120                 ACPM MC, DHULE       NT1   97844
# 439  01120                 ACPM MC, DHULE       NT2   57519
# 440  01120                 ACPM MC, DHULE       NT3   48351
# 441  01120                 ACPM MC, DHULE       OBC   49848
# 442  01120                 ACPM MC, DHULE       EWS     N/A
# 443  01120                 ACPM MC, DHULE      OPEN   46511
# 444  01120                 ACPM MC, DHULE        D1     N/A
# 445  01120                 ACPM MC, DHULE        D2     N/A
# 446  01120                 ACPM MC, DHULE        D3     N/A
# 447  01120                 ACPM MC, DHULE        PH     N/A
# 448  01120                 ACPM MC, DHULE       MKB     N/A
# 449  01120                 ACPM MC, DHULE       NRI     N/A
# 450  01135     VVPF'S MED. COL, AHMEDNAGAR       SC  111339
# 451  01135     VVPF'S MED. COL, AHMEDNAGAR       ST  282949
# 452  01135     VVPF'S MED. COL, AHMEDNAGAR       VJ   78866
# 453  01135     VVPF'S MED. COL, AHMEDNAGAR      NT1  107832
# 454  01135     VVPF'S MED. COL, AHMEDNAGAR      NT2   59184
# 455  01135     VVPF'S MED. COL, AHMEDNAGAR      NT3   51830
# 456  01135     VVPF'S MED. COL, AHMEDNAGAR      OBC   56987
# 457  01135     VVPF'S MED. COL, AHMEDNAGAR      EWS     N/A
# 458  01135     VVPF'S MED. COL, AHMEDNAGAR     OPEN   56539
# 459  01135     VVPF'S MED. COL, AHMEDNAGAR       D1     N/A
# 460  01135     VVPF'S MED. COL, AHMEDNAGAR       D2     N/A
# 461  01135     VVPF'S MED. COL, AHMEDNAGAR       D3     N/A
# 462  01135     VVPF'S MED. COL, AHMEDNAGAR       PH     N/A
# 463  01135     VVPF'S MED. COL, AHMEDNAGAR      MKB     N/A
# 464  01135     VVPF'S MED. COL, AHMEDNAGAR      NRI  665889
# 465  01136              SKN MED.COL, PUNE        SC  105523
# 466  01136              SKN MED.COL, PUNE        ST  278611
# 467  01136              SKN MED.COL, PUNE        VJ   81261
# 468  01136              SKN MED.COL, PUNE       NT1  108196
# 469  01136              SKN MED.COL, PUNE       NT2   65607
# 470  01136              SKN MED.COL, PUNE       NT3   57966
# 471  01136              SKN MED.COL, PUNE       OBC   67439
# 472  01136              SKN MED.COL, PUNE       EWS     N/A
# 473  01136              SKN MED.COL, PUNE      OPEN   66022
# 474  01136              SKN MED.COL, PUNE        D1     N/A
# 475  01136              SKN MED.COL, PUNE        D2     N/A
# 476  01136              SKN MED.COL, PUNE        D3     N/A
# 477  01136              SKN MED.COL, PUNE        PH     N/A
# 478  01136              SKN MED.COL, PUNE       MKB     N/A
# 479  01136              SKN MED.COL, PUNE       NRI  693690
# 480  01137        ASHWINI MED.COL, SOLAPUR       SC  109944
# 481  01137        ASHWINI MED.COL, SOLAPUR       ST  289203
# 482  01137        ASHWINI MED.COL, SOLAPUR       VJ   81351
# 483  01137        ASHWINI MED.COL, SOLAPUR      NT1  109913
# 484  01137        ASHWINI MED.COL, SOLAPUR      NT2   61798
# 485  01137        ASHWINI MED.COL, SOLAPUR      NT3   55024
# 486  01137        ASHWINI MED.COL, SOLAPUR      OBC   68703
# 487  01137        ASHWINI MED.COL, SOLAPUR      EWS     N/A
# 488  01137        ASHWINI MED.COL, SOLAPUR     OPEN   65667
# 489  01137        ASHWINI MED.COL, SOLAPUR       D1     N/A
# 490  01137        ASHWINI MED.COL, SOLAPUR       D2     N/A
# 491  01137        ASHWINI MED.COL, SOLAPUR       D3     N/A
# 492  01137        ASHWINI MED.COL, SOLAPUR       PH     N/A
# 493  01137        ASHWINI MED.COL, SOLAPUR      MKB     N/A
# 494  01137        ASHWINI MED.COL, SOLAPUR      NRI  622571
# 495  01138         DR U. PATIL MC, JALGAON       SC  110910
# 496  01138         DR U. PATIL MC, JALGAON       ST  290561
# 497  01138         DR U. PATIL MC, JALGAON       VJ   76370
# 498  01138         DR U. PATIL MC, JALGAON      NT1  109515
# 499  01138         DR U. PATIL MC, JALGAON      NT2   53345
# 500  01138         DR U. PATIL MC, JALGAON      NT3   51470
# 501  01138         DR U. PATIL MC, JALGAON      OBC   52081
# 502  01138         DR U. PATIL MC, JALGAON      EWS     N/A
# 503  01138         DR U. PATIL MC, JALGAON     OPEN   51986
# 504  01138         DR U. PATIL MC, JALGAON       D1     N/A
# 505  01138         DR U. PATIL MC, JALGAON       D2     N/A
# 506  01138         DR U. PATIL MC, JALGAON       D3     N/A
# 507  01138         DR U. PATIL MC, JALGAON       PH     N/A
# 508  01138         DR U. PATIL MC, JALGAON      MKB     N/A
# 509  01138         DR U. PATIL MC, JALGAON      NRI  628876
# 510  01139        WALAWALKAR MC, RATNAGIRI       SC  113133
# 511  01139        WALAWALKAR MC, RATNAGIRI       ST  290569
# 512  01139        WALAWALKAR MC, RATNAGIRI       VJ   82283
# 513  01139        WALAWALKAR MC, RATNAGIRI      NT1  109125
# 514  01139        WALAWALKAR MC, RATNAGIRI      NT2   66363
# 515  01139        WALAWALKAR MC, RATNAGIRI      NT3   63677
# 516  01139        WALAWALKAR MC, RATNAGIRI      OBC   68454
# 517  01139        WALAWALKAR MC, RATNAGIRI      EWS     N/A
# 518  01139        WALAWALKAR MC, RATNAGIRI     OPEN   69627
# 519  01139        WALAWALKAR MC, RATNAGIRI       D1     N/A
# 520  01139        WALAWALKAR MC, RATNAGIRI       D2     N/A
# 521  01139        WALAWALKAR MC, RATNAGIRI       D3     N/A
# 522  01139        WALAWALKAR MC, RATNAGIRI       PH     N/A
# 523  01139        WALAWALKAR MC, RATNAGIRI      MKB     N/A
# 524  01139        WALAWALKAR MC, RATNAGIRI      NRI  492223
# 525  01143  PIMS ISLAMPUR, ISLAMPUR,SANGLI       SC  114619
# 526  01143  PIMS ISLAMPUR, ISLAMPUR,SANGLI       ST  300076
# 527  01143  PIMS ISLAMPUR, ISLAMPUR,SANGLI       VJ   80806
# 528  01143  PIMS ISLAMPUR, ISLAMPUR,SANGLI      NT1  102724
# 529  01143  PIMS ISLAMPUR, ISLAMPUR,SANGLI      NT2   66004
# 530  01143  PIMS ISLAMPUR, ISLAMPUR,SANGLI      NT3   66419
# 531  01143  PIMS ISLAMPUR, ISLAMPUR,SANGLI      OBC   66449
# 532  01143  PIMS ISLAMPUR, ISLAMPUR,SANGLI      EWS     N/A
# 533  01143  PIMS ISLAMPUR, ISLAMPUR,SANGLI     OPEN   68687
# 534  01143  PIMS ISLAMPUR, ISLAMPUR,SANGLI       D1     N/A
# 535  01143  PIMS ISLAMPUR, ISLAMPUR,SANGLI       D2     N/A
# 536  01143  PIMS ISLAMPUR, ISLAMPUR,SANGLI       D3     N/A
# 537  01143  PIMS ISLAMPUR, ISLAMPUR,SANGLI       PH     N/A
# 538  01143  PIMS ISLAMPUR, ISLAMPUR,SANGLI      MKB     N/A
# 539  01143  PIMS ISLAMPUR, ISLAMPUR,SANGLI      NRI  559203
# 540  01144      SMBT MC NASHIK, NANDIHILLS       SC  111901
# 541  01144      SMBT MC NASHIK, NANDIHILLS       ST  287052
# 542  01144      SMBT MC NASHIK, NANDIHILLS       VJ   81876
# 543  01144      SMBT MC NASHIK, NANDIHILLS      NT1  118912
# 544  01144      SMBT MC NASHIK, NANDIHILLS      NT2   67639
# 545  01144      SMBT MC NASHIK, NANDIHILLS      NT3   69478
# 546  01144      SMBT MC NASHIK, NANDIHILLS      OBC   70996
# 547  01144      SMBT MC NASHIK, NANDIHILLS      EWS     N/A
# 548  01144      SMBT MC NASHIK, NANDIHILLS     OPEN   70762
# 549  01144      SMBT MC NASHIK, NANDIHILLS       D1     N/A
# 550  01144      SMBT MC NASHIK, NANDIHILLS       D2     N/A
# 551  01144      SMBT MC NASHIK, NANDIHILLS       D3     N/A
# 552  01144      SMBT MC NASHIK, NANDIHILLS       PH     N/A
# 553  01144      SMBT MC NASHIK, NANDIHILLS      MKB     N/A
# 554  01144      SMBT MC NASHIK, NANDIHILLS      NRI  612997
# 555  01147             VEDANTA MC, PALGHAR       SC  135851
# 556  01147             VEDANTA MC, PALGHAR       ST     N/A
# 557  01147             VEDANTA MC, PALGHAR       VJ     N/A
# 558  01147             VEDANTA MC, PALGHAR      NT1     N/A
# 559  01147             VEDANTA MC, PALGHAR      NT2     N/A
# 560  01147             VEDANTA MC, PALGHAR      NT3     N/A
# 561  01147             VEDANTA MC, PALGHAR      OBC  126494
# 562  01147             VEDANTA MC, PALGHAR      EWS     N/A
# 563  01147             VEDANTA MC, PALGHAR     OPEN  124651
# 564  01147             VEDANTA MC, PALGHAR       D1     N/A
# 565  01147             VEDANTA MC, PALGHAR       D2     N/A
# 566  01147             VEDANTA MC, PALGHAR       D3     N/A
# 567  01147             VEDANTA MC, PALGHAR       PH     N/A
# 568  01147             VEDANTA MC, PALGHAR      MKB     N/A
# 569  01147             VEDANTA MC, PALGHAR      NRI  677304
# 570  01152       SSPM MC, KUDAL SINDHUDURG       SC  115349
# 571  01152       SSPM MC, KUDAL SINDHUDURG       ST  292283
# 572  01152       SSPM MC, KUDAL SINDHUDURG       VJ   86441
# 573  01152       SSPM MC, KUDAL SINDHUDURG      NT1  122023
# 574  01152       SSPM MC, KUDAL SINDHUDURG      NT2   71172
# 575  01152       SSPM MC, KUDAL SINDHUDURG      NT3   71751
# 576  01152       SSPM MC, KUDAL SINDHUDURG      OBC   73974
# 577  01152       SSPM MC, KUDAL SINDHUDURG      EWS     N/A
# 578  01152       SSPM MC, KUDAL SINDHUDURG     OPEN   73508
# 579  01152       SSPM MC, KUDAL SINDHUDURG       D1     N/A
# 580  01152       SSPM MC, KUDAL SINDHUDURG       D2     N/A
# 581  01152       SSPM MC, KUDAL SINDHUDURG       D3     N/A
# 582  01152       SSPM MC, KUDAL SINDHUDURG       PH     N/A
# 583  01152       SSPM MC, KUDAL SINDHUDURG      MKB     N/A
# 584  01152       SSPM MC, KUDAL SINDHUDURG      NRI  660635
# 585  01223            NKP SALVE MC, NAGPUR       SC  103765
# 586  01223            NKP SALVE MC, NAGPUR       ST  296753
# 587  01223            NKP SALVE MC, NAGPUR       VJ   82798
# 588  01223            NKP SALVE MC, NAGPUR      NT1  101653
# 589  01223            NKP SALVE MC, NAGPUR      NT2   52030
# 590  01223            NKP SALVE MC, NAGPUR      NT3   58465
# 591  01223            NKP SALVE MC, NAGPUR      OBC   60079
# 592  01223            NKP SALVE MC, NAGPUR      EWS     N/A
# 593  01223            NKP SALVE MC, NAGPUR     OPEN   59144
# 594  01223            NKP SALVE MC, NAGPUR       D1     N/A
# 595  01223            NKP SALVE MC, NAGPUR       D2     N/A
# 596  01223            NKP SALVE MC, NAGPUR       D3     N/A
# 597  01223            NKP SALVE MC, NAGPUR       PH     N/A
# 598  01223            NKP SALVE MC, NAGPUR      MKB     N/A
# 599  01223            NKP SALVE MC, NAGPUR      NRI  671486
# 600  01225                 PDMC, AMRAVATI        SC  110354
# 601  01225                 PDMC, AMRAVATI        ST  290995
# 602  01225                 PDMC, AMRAVATI        VJ   76666
# 603  01225                 PDMC, AMRAVATI       NT1  102059
# 604  01225                 PDMC, AMRAVATI       NT2   59936
# 605  01225                 PDMC, AMRAVATI       NT3   65441
# 606  01225                 PDMC, AMRAVATI       OBC   58714
# 607  01225                 PDMC, AMRAVATI       EWS     N/A
# 608  01225                 PDMC, AMRAVATI      OPEN   60151
# 609  01225                 PDMC, AMRAVATI        D1     N/A
# 610  01225                 PDMC, AMRAVATI        D2     N/A
# 611  01225                 PDMC, AMRAVATI        D3     N/A
# 612  01225                 PDMC, AMRAVATI        PH     N/A
# 613  01225                 PDMC, AMRAVATI       MKB     N/A
# 614  01225                 PDMC, AMRAVATI       NRI  674599
# 615  01330                MIMSR MC, LATUR        SC  110061
# 616  01330                MIMSR MC, LATUR        ST  282997
# 617  01330                MIMSR MC, LATUR        VJ   77449
# 618  01330                MIMSR MC, LATUR       NT1  111863
# 619  01330                MIMSR MC, LATUR       NT2   60668
# 620  01330                MIMSR MC, LATUR       NT3   51452
# 621  01330                MIMSR MC, LATUR       OBC   52064
# 622  01330                MIMSR MC, LATUR       EWS     N/A
# 623  01330                MIMSR MC, LATUR      OPEN   52317
# 624  01330                MIMSR MC, LATUR        D1     N/A
# 625  01330                MIMSR MC, LATUR        D2     N/A
# 626  01330                MIMSR MC, LATUR        D3     N/A
# 627  01330                MIMSR MC, LATUR        PH     N/A
# 628  01330                MIMSR MC, LATUR       MKB     N/A
# 629  01330                MIMSR MC, LATUR       NRI  805212
# 630  01345                   IIMSR JALNA,        SC     N/A
# 631  01345                   IIMSR JALNA,        ST     N/A
# 632  01345                   IIMSR JALNA,        VJ     N/A
# 633  01345                   IIMSR JALNA,       NT1     N/A
# 634  01345                   IIMSR JALNA,       NT2     N/A
# 635  01345                   IIMSR JALNA,       NT3     N/A
# 636  01345                   IIMSR JALNA,       OBC     N/A
# 637  01345                   IIMSR JALNA,       EWS     N/A
# 638  01345                   IIMSR JALNA,      OPEN   70608
# 639  01345                   IIMSR JALNA,        D1     N/A
# 640  01345                   IIMSR JALNA,        D2     N/A
# 641  01345                   IIMSR JALNA,        D3     N/A
# 642  01345                   IIMSR JALNA,        PH     N/A
# 643  01345                   IIMSR JALNA,       MKB     N/A
# 644  01345                   IIMSR JALNA,       NRI  792219
# 645  02101                      GDC,MUMBAI       SC  152812
# 646  02101                      GDC,MUMBAI       ST  359066
# 647  02101                      GDC,MUMBAI       VJ  152946
# 648  02101                      GDC,MUMBAI      NT1  168578
# 649  02101                      GDC,MUMBAI      NT2   78027
# 650  02101                      GDC,MUMBAI      NT3   81443
# 651  02101                      GDC,MUMBAI      OBC   78265
# 652  02101                      GDC,MUMBAI      EWS   67363
# 653  02101                      GDC,MUMBAI     OPEN   72908
# 654  02101                      GDC,MUMBAI       D1   96827
# 655  02101                      GDC,MUMBAI       D2   76857
# 656  02101                      GDC,MUMBAI       D3  128946
# 657  02101                      GDC,MUMBAI       PH  144145
# 658  02101                      GDC,MUMBAI      MKB  101955
# 659  02101                      GDC,MUMBAI      NRI     N/A
# 660  02102                   NairDC,MUMBAI       SC  173789
# 661  02102                   NairDC,MUMBAI       ST  399472
# 662  02102                   NairDC,MUMBAI       VJ  108906
# 663  02102                   NairDC,MUMBAI      NT1  188678
# 664  02102                   NairDC,MUMBAI      NT2   81576
# 665  02102                   NairDC,MUMBAI      NT3   77117
# 666  02102                   NairDC,MUMBAI      OBC   84083
# 667  02102                   NairDC,MUMBAI      EWS   76229
# 668  02102                   NairDC,MUMBAI     OPEN   74512
# 669  02102                   NairDC,MUMBAI       D1   85061
# 670  02102                   NairDC,MUMBAI       D2  105178
# 671  02102                   NairDC,MUMBAI       D3     N/A
# 672  02102                   NairDC,MUMBAI       PH   67318
# 673  02102                   NairDC,MUMBAI      MKB     N/A
# 674  02102                   NairDC,MUMBAI      NRI     N/A
# 675  02207                      GDC,NAGPUR       SC  149826
# 676  02207                      GDC,NAGPUR       ST     N/A
# 677  02207                      GDC,NAGPUR       VJ     N/A
# 678  02207                      GDC,NAGPUR      NT1  171880
# 679  02207                      GDC,NAGPUR      NT2   76013
# 680  02207                      GDC,NAGPUR      NT3   94865
# 681  02207                      GDC,NAGPUR      OBC   74756
# 682  02207                      GDC,NAGPUR      EWS   80784
# 683  02207                      GDC,NAGPUR     OPEN   80177
# 684  02207                      GDC,NAGPUR       D1  102921
# 685  02207                      GDC,NAGPUR       D2  106365
# 686  02207                      GDC,NAGPUR       D3     N/A
# 687  02207                      GDC,NAGPUR       PH  362275
# 688  02207                      GDC,NAGPUR      MKB     N/A
# 689  02207                      GDC,NAGPUR      NRI     N/A
# 690  02313                  GDC,AURANGABAD       SC  174525
# 691  02313                  GDC,AURANGABAD       ST  368820
# 692  02313                  GDC,AURANGABAD       VJ  115157
# 693  02313                  GDC,AURANGABAD      NT1  176144
# 694  02313                  GDC,AURANGABAD      NT2   88131
# 695  02313                  GDC,AURANGABAD      NT3   93002
# 696  02313                  GDC,AURANGABAD      OBC   89119
# 697  02313                  GDC,AURANGABAD      EWS   79609
# 698  02313                  GDC,AURANGABAD     OPEN   79268
# 699  02313                  GDC,AURANGABAD       D1   97579
# 700  02313                  GDC,AURANGABAD       D2  110758
# 701  02313                  GDC,AURANGABAD       D3     N/A
# 702  02313                  GDC,AURANGABAD       PH   73625
# 703  02313                  GDC,AURANGABAD      MKB     N/A
# 704  02313                  GDC,AURANGABAD      NRI     N/A
# 705  02104             V Patil DC, SANGLI        SC  224003
# 706  02104             V Patil DC, SANGLI        ST     N/A
# 707  02104             V Patil DC, SANGLI        VJ     N/A
# 708  02104             V Patil DC, SANGLI       NT1     N/A
# 709  02104             V Patil DC, SANGLI       NT2     N/A
# 710  02104             V Patil DC, SANGLI       NT3     N/A
# 711  02104             V Patil DC, SANGLI       OBC  155070
# 712  02104             V Patil DC, SANGLI       EWS     N/A
# 713  02104             V Patil DC, SANGLI      OPEN  280840
# 714  02104             V Patil DC, SANGLI        D1     N/A
# 715  02104             V Patil DC, SANGLI        D2     N/A
# 716  02104             V Patil DC, SANGLI        D3     N/A
# 717  02104             V Patil DC, SANGLI        PH     N/A
# 718  02104             V Patil DC, SANGLI       MKB     N/A
# 719  02104             V Patil DC, SANGLI       NRI  791080
# 720  02105                 MGVM DC, NASIK        SC  310754
# 721  02105                 MGVM DC, NASIK        ST  577719
# 722  02105                 MGVM DC, NASIK        VJ  196146
# 723  02105                 MGVM DC, NASIK       NT1  382832
# 724  02105                 MGVM DC, NASIK       NT2  338090
# 725  02105                 MGVM DC, NASIK       NT3     N/A
# 726  02105                 MGVM DC, NASIK       OBC  302717
# 727  02105                 MGVM DC, NASIK       EWS     N/A
# 728  02105                 MGVM DC, NASIK      OPEN  331029
# 729  02105                 MGVM DC, NASIK        D1     N/A
# 730  02105                 MGVM DC, NASIK        D2     N/A
# 731  02105                 MGVM DC, NASIK        D3     N/A
# 732  02105                 MGVM DC, NASIK        PH     N/A
# 733  02105                 MGVM DC, NASIK       MKB     N/A
# 734  02105                 MGVM DC, NASIK       NRI  781994
# 735  02115             YMT DC, NEW MUMBAI        SC  272656
# 736  02115             YMT DC, NEW MUMBAI        ST  543228
# 737  02115             YMT DC, NEW MUMBAI        VJ  264336
# 738  02115             YMT DC, NEW MUMBAI       NT1  198031
# 739  02115             YMT DC, NEW MUMBAI       NT2  195294
# 740  02115             YMT DC, NEW MUMBAI       NT3  224511
# 741  02115             YMT DC, NEW MUMBAI       OBC  301856
# 742  02115             YMT DC, NEW MUMBAI       EWS     N/A
# 743  02115             YMT DC, NEW MUMBAI      OPEN  259936
# 744  02115             YMT DC, NEW MUMBAI        D1     N/A
# 745  02115             YMT DC, NEW MUMBAI        D2     N/A
# 746  02115             YMT DC, NEW MUMBAI        D3     N/A
# 747  02115             YMT DC, NEW MUMBAI        PH     N/A
# 748  02115             YMT DC, NEW MUMBAI       MKB     N/A
# 749  02115             YMT DC, NEW MUMBAI       NRI     N/A
# 750  02116     D Y PATIL DC, LOHGAON, PUNE       SC  316571
# 751  02116     D Y PATIL DC, LOHGAON, PUNE       ST  524837
# 752  02116     D Y PATIL DC, LOHGAON, PUNE       VJ  277624
# 753  02116     D Y PATIL DC, LOHGAON, PUNE      NT1     N/A
# 754  02116     D Y PATIL DC, LOHGAON, PUNE      NT2     N/A
# 755  02116     D Y PATIL DC, LOHGAON, PUNE      NT3  170166
# 756  02116     D Y PATIL DC, LOHGAON, PUNE      OBC  349989
# 757  02116     D Y PATIL DC, LOHGAON, PUNE      EWS     N/A
# 758  02116     D Y PATIL DC, LOHGAON, PUNE     OPEN  303661
# 759  02116     D Y PATIL DC, LOHGAON, PUNE       D1     N/A
# ...
# 742                N/A    B.D.S.                        N/A
# 743                341    B.D.S.                        N/A
# 744                N/A    B.D.S.                        N/A
# 745                N/A    B.D.S.                        N/A
# 746                N/A    B.D.S.                        N/A
# 747                N/A    B.D.S.                        N/A
# 748                N/A    B.D.S.                        N/A
# 749                N/A    B.D.S.                        N/A
# 750                304    B.D.S.                        N/A
# 751                200    B.D.S.                        N/A
# 752                329    B.D.S.                        N/A
# 753                N/A    B.D.S.                        N/A
# 754                N/A    B.D.S.                        N/A
# 755                413    B.D.S.                        N/A
# 756                284    B.D.S.                        N/A
# 757                N/A    B.D.S.                        N/A
# 758                312    B.D.S.                        N/A
# 759                N/A    B.D.S.                        N/A
# 760                N/A    B.D.S.                        N/A
# 761                N/A    B.D.S.                        N/A
# 762                N/A    B.D.S.                        N/A
# 763                N/A    B.D.S.                        N/A
# 764                N/A    B.D.S.                        N/A
# 765                270    B.D.S.                        N/A
# 766                190    B.D.S.                        N/A
# 767                N/A    B.D.S.                        N/A
# 768                319    B.D.S.                        N/A
# 769                270    B.D.S.                        N/A
# 770                297    B.D.S.                        N/A
# 771                267    B.D.S.                        N/A
# 772                N/A    B.D.S.                        N/A
# 773                272    B.D.S.                        N/A
# 774                N/A    B.D.S.                        N/A
# 775                N/A    B.D.S.                        N/A
# 776                N/A    B.D.S.                        N/A
# 777                N/A    B.D.S.                        N/A
# 778                N/A    B.D.S.                        N/A
# 779                130    B.D.S.                        N/A
# 780                270    B.D.S.                        N/A
# 781                208    B.D.S.                        N/A
# 782                300    B.D.S.                        N/A
# 783                N/A    B.D.S.                        N/A
# 784                336    B.D.S.                        N/A
# 785                274    B.D.S.                        N/A
# 786                268    B.D.S.                        N/A
# 787                N/A    B.D.S.                        N/A
# 788                276    B.D.S.                        N/A
# 789                N/A    B.D.S.                        N/A
# 790                N/A    B.D.S.                        N/A
# 791                N/A    B.D.S.                        N/A
# 792                N/A    B.D.S.                        N/A
# 793                N/A    B.D.S.                        N/A
# 794                152    B.D.S.                        N/A
# 795                N/A    B.D.S.                        N/A
# 796                N/A    B.D.S.                        N/A
# 797                N/A    B.D.S.                        N/A
# 798                N/A    B.D.S.                        N/A
# 799                N/A    B.D.S.                        N/A
# 800                N/A    B.D.S.                        N/A
# 801                N/A    B.D.S.                        N/A
# 802                N/A    B.D.S.                        N/A
# 803                267    B.D.S.                        N/A
# 804                N/A    B.D.S.                        N/A
# 805                N/A    B.D.S.                        N/A
# 806                N/A    B.D.S.                        N/A
# 807                N/A    B.D.S.                        N/A
# 808                N/A    B.D.S.                        N/A
# 809                N/A    B.D.S.                        N/A
# 810                270    B.D.S.                        N/A
# 811                175    B.D.S.                        N/A
# 812                N/A    B.D.S.                        N/A
# 813                321    B.D.S.                        N/A
# 814                290    B.D.S.                        N/A
# 815                399    B.D.S.                        N/A
# 816                339    B.D.S.                        N/A
# 817                N/A    B.D.S.                        N/A
# 818                303    B.D.S.                        N/A
# 819                N/A    B.D.S.                        N/A
# 820                N/A    B.D.S.                        N/A
# 821                N/A    B.D.S.                        N/A
# 822                N/A    B.D.S.                        N/A
# 823                N/A    B.D.S.                        N/A
# 824                197    B.D.S.                        N/A
# 825                272    B.D.S.                        N/A
# 826                184    B.D.S.                        N/A
# 827                275    B.D.S.                        N/A
# 828                N/A    B.D.S.                        N/A
# 829                385    B.D.S.                        N/A
# 830                260    B.D.S.                        N/A
# 831                277    B.D.S.                        N/A
# 832                N/A    B.D.S.                        N/A
# 833                288    B.D.S.                        N/A
# 834                N/A    B.D.S.                        N/A
# 835                N/A    B.D.S.                        N/A
# 836                N/A    B.D.S.                        N/A
# 837                N/A    B.D.S.                        N/A
# 838                N/A    B.D.S.                        N/A
# 839                N/A    B.D.S.                        N/A
# 840                340    B.D.S.                        N/A
# 841                226    B.D.S.                        N/A
# 842                320    B.D.S.                        N/A
# 843                340    B.D.S.                        N/A
# 844                308    B.D.S.                        N/A
# 845                450    B.D.S.                        N/A
# 846                377    B.D.S.                        N/A
# 847                N/A    B.D.S.                        N/A
# 848                342    B.D.S.                        N/A
# 849                N/A    B.D.S.                        N/A
# 850                N/A    B.D.S.                        N/A
# 851                N/A    B.D.S.                        N/A
# 852                N/A    B.D.S.                        N/A
# 853                N/A    B.D.S.                        N/A
# 854                N/A    B.D.S.                        N/A
# 855                351    B.D.S.                        N/A
# 856                185    B.D.S.                        N/A
# 857                N/A    B.D.S.                        N/A
# 858                N/A    B.D.S.                        N/A
# 859                395    B.D.S.                        N/A
# 860                421    B.D.S.                        N/A
# 861                305    B.D.S.                        N/A
# 862                N/A    B.D.S.                        N/A
# 863                357    B.D.S.                        N/A
# 864                N/A    B.D.S.                        N/A
# 865                N/A    B.D.S.                        N/A
# 866                N/A    B.D.S.                        N/A
# 867                N/A    B.D.S.                        N/A
# 868                N/A    B.D.S.                        N/A
# 869                N/A    B.D.S.                        N/A
# 870                284    B.D.S.                        N/A
# 871                205    B.D.S.                        N/A
# 872                317    B.D.S.                        N/A
# 873                291    B.D.S.                        N/A
# 874                284    B.D.S.                        N/A
# 875                362    B.D.S.                        N/A
# 876                279    B.D.S.                        N/A
# 877                N/A    B.D.S.                        N/A
# 878                300    B.D.S.                        N/A
# 879                N/A    B.D.S.                        N/A
# 880                N/A    B.D.S.                        N/A
# 881                N/A    B.D.S.                        N/A
# 882                N/A    B.D.S.                        N/A
# 883                N/A    B.D.S.                        N/A
# 884                145    B.D.S.                        N/A
# 885                273    B.D.S.                        N/A
# 886                171    B.D.S.                        N/A
# 887                N/A    B.D.S.                        N/A
# 888                384    B.D.S.                        N/A
# 889                275    B.D.S.                        N/A
# 890                296    B.D.S.                        N/A
# 891                270    B.D.S.                        N/A
# 892                N/A    B.D.S.                        N/A
# 893                280    B.D.S.                        N/A
# 894                N/A    B.D.S.                        N/A
# 895                N/A    B.D.S.                        N/A
# 896                N/A    B.D.S.                        N/A
# 897                N/A    B.D.S.                        N/A
# 898                N/A    B.D.S.                        N/A
# 899                125    B.D.S.                        N/A
# 900                265    B.D.S.                        N/A
# 901                272    B.D.S.                        N/A
# 902                353    B.D.S.                        N/A
# 903                256    B.D.S.                        N/A
# 904                288    B.D.S.                        N/A
# 905                317    B.D.S.                        N/A
# 906                260    B.D.S.                        N/A
# 907                N/A    B.D.S.                        N/A
# 908                265    B.D.S.                        N/A
# 909                N/A    B.D.S.                        N/A
# 910                N/A    B.D.S.                        N/A
# 911                N/A    B.D.S.                        N/A
# 912                N/A    B.D.S.                        N/A
# 913                N/A    B.D.S.                        N/A
# 914                137    B.D.S.                        N/A
# 915                269    B.D.S.                        N/A
# 916                211    B.D.S.                        N/A
# 917                267    B.D.S.                        N/A
# 918                312    B.D.S.                        N/A
# 919                293    B.D.S.                        N/A
# 920                373    B.D.S.                        N/A
# 921                272    B.D.S.                        N/A
# 922                N/A    B.D.S.                        N/A
# 923                272    B.D.S.                        N/A
# 924                N/A    B.D.S.                        N/A
# 925                N/A    B.D.S.                        N/A
# 926                N/A    B.D.S.                        N/A
# 927                N/A    B.D.S.                        N/A
# 928                N/A    B.D.S.                        N/A
# 929                189    B.D.S.                        N/A
# 930                293    B.D.S.                        N/A
# 931                177    B.D.S.                        N/A
# 932                369    B.D.S.                        N/A
# 933                N/A    B.D.S.                        N/A
# 934                N/A    B.D.S.                        N/A
# 935                N/A    B.D.S.                        N/A
# 936                258    B.D.S.                        N/A
# 937                N/A    B.D.S.                        N/A
# 938                264    B.D.S.                        N/A
# 939                N/A    B.D.S.                        N/A
# 940                N/A    B.D.S.                        N/A
# 941                N/A    B.D.S.                        N/A
# 942                N/A    B.D.S.                        N/A
# 943                N/A    B.D.S.                        N/A
# 944                N/A    B.D.S.                        N/A
# 945                384    B.D.S.                        N/A
# 946                172    B.D.S.                        N/A
# 947                371    B.D.S.                        N/A
# 948                420    B.D.S.                        N/A
# 949                400    B.D.S.                        N/A
# 950                351    B.D.S.                        N/A
# 951                302    B.D.S.                        N/A
# 952                N/A    B.D.S.                        N/A
# 953                322    B.D.S.                        N/A
# 954                N/A    B.D.S.                        N/A
# 955                N/A    B.D.S.                        N/A
# 956                N/A    B.D.S.                        N/A
# 957                N/A    B.D.S.                        N/A
# 958                N/A    B.D.S.                        N/A
# 959                156    B.D.S.                        N/A
# 960                257    B.D.S.                        N/A
# 961                161    B.D.S.                        N/A
# 962                N/A    B.D.S.                        N/A
# 963                346    B.D.S.                        N/A
# 964                N/A    B.D.S.                        N/A
# 965                316    B.D.S.                        N/A
# 966                259    B.D.S.                        N/A
# 967                N/A    B.D.S.                        N/A
# 968                260    B.D.S.                        N/A
# 969                N/A    B.D.S.                        N/A
# 970                N/A    B.D.S.                        N/A
# 971                N/A    B.D.S.                        N/A
# 972                N/A    B.D.S.                        N/A
# 973                N/A    B.D.S.                        N/A
# 974                N/A    B.D.S.                        N/A
# 975                265    B.D.S.                        N/A
# 976                166    B.D.S.                        N/A
# 977                288    B.D.S.                        N/A
# 978                330    B.D.S.                        N/A
# 979                268    B.D.S.                        N/A
# 980                258    B.D.S.                        N/A
# 981                261    B.D.S.                        N/A
# 982                N/A    B.D.S.                        N/A
# 983                270    B.D.S.                        N/A
# 984                N/A    B.D.S.                        N/A
# 985                N/A    B.D.S.                        N/A
# 986                N/A    B.D.S.                        N/A
# 987                N/A    B.D.S.                        N/A
# 988                N/A    B.D.S.                        N/A
# 989                N/A    B.D.S.                        N/A
# 990                375    B.D.S.                        N/A
# 991                172    B.D.S.                        N/A
# 992                383    B.D.S.                        N/A
# 993                N/A    B.D.S.                        N/A
# 994                336    B.D.S.                        N/A
# 995                352    B.D.S.                        N/A
# 996                348    B.D.S.                        N/A
# 997                N/A    B.D.S.                        N/A
# 998                338    B.D.S.                        N/A
# 999                N/A    B.D.S.                        N/A

# %%
final.to_excel("Output.xlsx", index=True, index_label="Sr. No.")
