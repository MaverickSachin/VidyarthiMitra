# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_rows', 1000)
pd.set_option('display.max_columns', 1000)

# %%
df = pd.read_excel("Input - NEET Opening Closing 2020.xlsx")

# %%
df.head(20)
# Out:
#    Admissions to Health Science Courses, 2020-2021               Unnamed: 1  \
# 0                                              NaN                      NaN
# 1                                              NaN    Sr Code  College Name
# 2                                                1        01101 GMC, MUMBAI
# 3                                              NaN                      NaN
# 4                                                2   01102 Tilak MC, MUMBAI
# 5                                              NaN                      NaN
# 6                                                3       01103 GSMC, MUMBAI
# 7                                              NaN                      NaN
# 8                                                4    01104 Nair MC, MUMBAI
# 9                                              NaN                      NaN
# 10                                               5  01109 RGMC KALVA, THANE
# 11                                             NaN                      NaN
# 12                                               6         01110 BJMC, PUNE
# 13                                             NaN                      NaN
# 14                                               7    01114 V M MC, SOLAPUR
# 15                                             NaN                      NaN
# 16                                               8         01115 GMC, MIRAJ
# 17                                             NaN                      NaN
# 18                                               9   01119 B HIRE MC, DHULE
# 19                                             NaN                      NaN
#
#    Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0         NaN        NaN        NaN
# 1         NaN         SC         ST
# 2         S :      47384     180913
# 3         M :        552        404
# 4         S :      60922     261328
# 5         M :        533        340
# 6         S :      29063     147045
# 7         M :        582        435
# 8         S :      56795     253139
# 9         M :        539        346
# 10        S :      72172     269328
# 11        M :        518        335
# 12        S :      55684     140466
# 13        M :        540        441
# 14        S :      84587     238220
# 15        M :        502        357
# 16        S :      92140     240855
# 17        M :        493        355
# 18        S :     100221     280419
# 19        M :        484        327
#
#                                            Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0   Quotawise List of Last Admitted Candidates In ...        NaN        NaN
# 1                                                  VJ        NT1        NT2
# 2                                               22048      32096      12268
# 3                                                 595        577        618
# 4                                               36398      39169      22834
# 5                                                 569        565        594
# 6                                                7264      26937       8618
# 7                                                 635        586        630
# 8                                               17825      42232      16036
# 9                                                 605        560        609
# 10                                              43343      67581      37511
# 11                                                558        524        567
# 12                                              34772      51451      21820
# 13                                                572        546        596
# 14                                              63566      82390      37430
# 15                                                529        505        568
# 16                                              66194      77389      34272
# 17                                                526        511        573
# 18                                              70588      87916      43407
# 19                                                520        498        558
#
#    Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13  \
# 0         NaN        NaN         NaN         NaN         NaN         NaN
# 1         NT3        OBC         EWS        OPEN          D1          D2
# 2        7007      12081       13670        8971       20470        4111
# 3         635        619         615         629         599         649
# 4       11428      14492       15409        8305       30897       14019
# 5         621        612         610         631         579         614
# 6        3798       5545        4941        2669        3971        5745
# 7         650        641         645         657         650         641
# 8       10666       9506       12792        8609       27720        9051
# 9         623        627         617         630         585         628
# 10      16730      21200       20828       12484       37711       23751
# 11        607        597         598         618         567         592
# 12       9881      12789       14474        7296       23049       12775
# 13        626        617         612         635         593         617
# 14      21601      25850       26482       20361       50754       27482
# 15        596        588         587         599         547         585
# 16      24844      29693       27311       21929       47798       40536
# 17        590        581         585         596         552         562
# 18      36341      35122       34764       30675       59671       52841
# 19        569        571         572         579         535         544
#
#    Unnamed: 14 Unnamed: 15 Unnamed: 16 Unnamed: 17
# 0          NaN         NaN         NaN         NaN
# 1           D3          PH         MKB         NaN
# 2         9448      624419       33135         NaN
# 3          627         164         575         NaN
# 4        22912      726401         NaN         NaN
# 5          594         135         NaN         NaN
# 6         8296      620669         NaN         NaN
# 7          631         165         NaN         NaN
# 8        18551      532883         NaN         NaN
# 9          603         197         NaN         NaN
# 10       38054      731222         NaN         NaN
# 11         567         133         NaN         NaN
# 12       11206      522516       23070         NaN
# 13         621         201         593         NaN
# 14       24549      627977       77446         NaN
# 15         591         163         511         NaN
# 16       64637      774731       80046         NaN
# 17         528         122         508         NaN
# 18       72813      794117         NaN         NaN
# 19         517         118         NaN         NaN
