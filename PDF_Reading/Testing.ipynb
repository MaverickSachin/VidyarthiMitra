# %%
import pandas as pd
import fitz  # this is pymupdf

# %%
with fitz.open("FE_CAP Round_I_2021.pdf") as doc:
    text = ""
    for page in doc:
        text += page.get_text()

    lines = text.split("\n")
    college_indexes, college_codes, college_names = [], [], []

    for index, line in enumerate(lines):
        if ' - ' in line:
            code = line.split(" - ")[0].strip()
            college = line.split("-")[1].strip()
            if 'college' in college.lower() or 'university' in college.lower():
                if (len(code) == 4) and code.isdigit():
                    if (code not in college_codes):
                        college_indexes.append(index)
                        college_codes.append(code)
                        college_names.append(college)
    
    last_college_index = college_indexes[-1]
    cleaned_college_names = [c[:-1] if c[-1] == '.' else c for c in college_names]
    cleaned_college_codes = [int(c) for c in college_codes]

# %%
college_indexes[-1]
# Out:
# 87311

# %%
lines[college_indexes[-1]:]
# Out:
# ["6938 - Shree Siddheshwar Women's College Of Engineering Solapur.",
#  '693824250F - Computer Science and Engineering',
#  'Status:',
#  'Un-Aided',
#  'Home University Seats Allotted to Home University Candidates',
#  'LOPENH',
#  'LSCH',
#  'LNT2H',
#  'LOBCH',
#  '  I',
#  '84564',
#  '(26.7293565)',
#  '98314',
#  '(4.8165736)',
#  '96109',
#  '(8.6176951)',
#  '93465',
#  '(12.7980055)',
#  'Stage',
#  'Other Than Home University Seats Allotted to Other Than Home University Candidates',
#  'LOPENO',
#  '  I',
#  '93058',
#  '(14.2756391)',
#  'Stage',
#  'Other Than Home University Seats Allotted to Home University Candidates',
#  'LOPENO',
#  'LOBCO',
#  '  I',
#  '85449',
#  '(25.2726609)',
#  '100468',
#  '(0.7056167)',
#  'Stage',
#  'State Level',
#  'EWS',
#  '  I',
#  '86929',
#  '(23.6405669)',
#  'Stage',
#  '1',
#  'Cut Off Indicates All India Merit No.; Figures in bracket Indicates JEE(Main) Score/MHT-CET Percentile.; AI to AI-All India Seats Allotted to All India Candidature Candidates.',
#  'D',
#  'i',
#  'r',
#  'State Common Entrance Test Cell',
#  'Cut Off List of All India Seats CAP Round I for Admission to First Year of Four Year Full Time Degree Courses in Engineering and Technology for the Academic Year 2021-22',
#  'Government of Maharashtra',
#  "6938 - Shree Siddheshwar Women's College Of Engineering Solapur.",
#  '693829350F - Electrical Engineering',
#  'Status:',
#  'Un-Aided',
#  'Home University Seats Allotted to Home University Candidates',
#  'LOPENH',
#  '  I',
#  '91774',
#  '(15.6759808)',
#  'Stage',
#  'Other Than Home University Seats Allotted to Other Than Home University Candidates',
#  'LOPENO',
#  '  I',
#  '92810',
#  '(14.9204746)',
#  'Stage',
#  '693837250F - Electronics and Telecommunication Engg',
#  'Status:',
#  'Un-Aided',
#  'Home University Seats Allotted to Home University Candidates',
#  'LOPENH',
#  '  I',
#  '65248',
#  '(49.5849968)',
#  'Stage',
#  'Other Than Home University Seats Allotted to Other Than Home University Candidates',
#  'LOPENO',
#  '  I',
#  '87518',
#  '(22.8953821)',
#  'Stage',
#  'State Level',
#  'EWS',
#  '  I',
#  '84126',
#  '(26.9383597)',
#  'Stage',
#  '1',
#  'Cut Off Indicates All India Merit No.; Figures in bracket Indicates JEE(Main) Score/MHT-CET Percentile.; AI to AI-All India Seats Allotted to All India Candidature Candidates.',
#  'D',
#  'i',
#  'r',
#  'State Common Entrance Test Cell',
#  'Cut Off List of All India Seats CAP Round I for Admission to First Year of Four Year Full Time Degree Courses in Engineering and Technology for the Academic Year 2021-22',
#  'Government of Maharashtra',
#  "6938 - Shree Siddheshwar Women's College Of Engineering Solapur.",
#  '693892550F - Computer Science and Engineering (Artificial Intelligence and Data Science)',
#  'Status:',
#  'Un-Aided',
#  'Home University Seats Allotted to Home University Candidates',
#  'LOPENH',
#  '  I',
#  '97541',
#  '(6.5584481)',
#  'Stage',
#  'Other Than Home University Seats Allotted to Other Than Home University Candidates',
#  'LOPENO',
#  '  I',
#  '62379',
#  '(52.2112775)',
#  'Stage',
#  'Other Than Home University Seats Allotted to Home University Candidates',
#  'LOPENO',
#  '  I',
#  '96596',
#  '(8.1817268)',
#  'Stage',
#  'State Level',
#  'EWS',
#  '  I',
#  '77392',
#  '(36.4202981)',
#  'Stage',
#  '1',
#  'Cut Off Indicates All India Merit No.; Figures in bracket Indicates JEE(Main) Score/MHT-CET Percentile.; AI to AI-All India Seats Allotted to All India Candidature Candidates.',
#  '']

# %%
college = lines[college_indexes[0]:college_indexes[1]]
college
# Out:
# ['1002 - Government College of Engineering, Amravati',
#  '100219110 - Civil Engineering',
#  'Status:',
#  'Government Autonomous',
#  'State Level',
#  'GOPENS',
#  'GSCS',
#  'GSTS',
#  'GVJS',
#  'GNT1S',
#  'GNT2S',
#  'GNT3S',
#  'GOBCS',
#  'LOPENS',
#  'LSCS',
#  'LSTS',
#  'LVJS',
#  'LNT1S',
#  'LNT2S',
#  'LOBCS',
#  'PWDOPENS',
#  'DEFOPENS',
#  'TFWS',
#  'DEFROBCS',
#  'EWS',
#  '  I',
#  '21750',
#  '(85.7691222)',
#  '32144',
#  '(78.5189539)',
#  '49581',
#  '(65.3394562)',
#  '30806',
#  '(79.5415810)',
#  '23850',
#  '(84.2624154)',
#  '23704',
#  '(84.4335948)',
#  '44825',
#  '(68.9918585)',
#  '25843',
#  '(83.0877787)',
#  '22019',
#  '(85.5868079)',
#  '27275',
#  '(82.0130279)',
#  '57303',
#  '(58.0509972)',
#  '33671',
#  '(77.3804659)',
#  '68369',
#  '(46.0655482)',
#  '47003',
#  '(67.2915815)',
#  '23336',
#  '(84.6567494)',
#  '62892',
#  '(51.9482809)',
#  '46444',
#  '(67.7749226)',
#  '16897',
#  '(88.8866448)',
#  '71028',
#  '(44.1945416)',
#  '26147',
#  '(82.7767101)',
#  'Stage',
#  '100224210 - Computer Science and Engineering',
#  'Status:',
#  'Government Autonomous',
#  'State Level',
#  'GOPENS',
#  'GSCS',
#  'GSTS',
#  'GVJS',
#  'GNT1S',
#  'GNT2S',
#  'GNT3S',
#  'GOBCS',
#  'LOPENS',
#  'LSCS',
#  'LSTS',
#  'LVJS',
#  'LNT1S',
#  'LNT2S',
#  'LOBCS',
#  'PWDOPENS',
#  'DEFOPENS',
#  'TFWS',
#  'PWDROBC',
#  'S',
#  'DEFROBCS',
#  'EWS',
#  '  I',
#  '4731',
#  '(96.8328566)',
#  '8734',
#  '(94.2649898)',
#  '32517',
#  '(78.1762608)',
#  '16689',
#  '(89.0926089)',
#  '9216',
#  '(93.9671026)',
#  '5013',
#  '(96.6278018)',
#  '10315',
#  '(93.2254498)',
#  '5452',
#  '(96.3605852)',
#  '4280',
#  '(97.1143109)',
#  '13443',
#  '(91.1411105)',
#  '24468',
#  '(83.9803841)',
#  '13177',
#  '(91.3860690)',
#  '8590',
#  '(94.3333506)',
#  '15015',
#  '(90.1502416)',
#  '5729',
#  '(96.2010124)',
#  '27025',
#  '(82.1745519)',
#  '11104',
#  '(92.7475757)',
#  '3541',
#  '(97.5903614)',
#  '42953',
#  '(70.7140758)',
#  '23851',
#  '(84.2624154)',
#  '5378',
#  '(96.3865715)',
#  'Stage',
#  '100224610 - Information Technology',
#  'Status:',
#  'Government Autonomous',
#  'State Level',
#  'GOPENS',
#  'GSCS',
#  'GSTS',
#  'GVJS',
#  'GNT1S',
#  'GNT2S',
#  'GNT3S',
#  'GOBCS',
#  'LOPENS',
#  'LSCS',
#  'LSTS',
#  'LVJS',
#  'LNT1S',
#  'LNT2S',
#  'LOBCS',
#  'PWDOPENS',
#  'DEFOPENS',
#  'TFWS',
#  'PWDROBC',
#  'S',
#  'DEFROBCS',
#  'EWS',
#  '  I',
#  '6919',
#  '(95.3951022)',
#  '15257',
#  '(90.0276575)',
#  '44970',
#  '(68.5685433)',
#  '22403',
#  '(85.2776363)',
#  '12800',
#  '(91.5971454)',
#  '10065',
#  '(93.3643237)',
#  '13598',
#  '(91.0594030)',
#  '7557',
#  '(94.9929881)',
#  '7932',
#  '(94.7678084)',
#  '17620',
#  '(88.4849114)',
#  '38033',
#  '(74.2590255)',
#  '28406',
#  '(81.2701101)',
#  '17143',
#  '(88.7526385)',
#  '17062',
#  '(88.7543704)',
#  '8290',
#  '(94.5367331)',
#  '62864',
#  '(51.9482809)',
#  '22103',
#  '(85.4775879)',
#  '5980',
#  '(96.0417728)',
#  '62924',
#  '(51.9482809)',
#  '24845',
#  '(83.6917866)',
#  '8743',
#  '(94.2649898)',
#  'Stage',
#  '100229310 - Electrical Engineering',
#  'Status:',
#  'Government Autonomous',
#  'State Level',
#  'GOPENS',
#  'GSCS',
#  'GSTS',
#  'GVJS',
#  'GNT1S',
#  'GNT2S',
#  'GNT3S',
#  'GOBCS',
#  'LOPENS',
#  'LSCS',
#  'LSTS',
#  'LVJS',
#  'LNT1S',
#  'LNT2S',
#  'LOBCS',
#  'PWDOPENS',
#  'DEFOPENS',
#  'TFWS',
#  'PWDRSCS',
#  'DEFROBCS',
#  'EWS',
#  '  I',
#  '18371',
#  '(87.9438958)',
#  '31678',
#  '(78.9161727)',
#  '42891',
#  '(70.7243564)',
#  '40873',
#  '(72.1238249)',
#  '34210',
#  '(77.2185430)',
#  '20292',
#  '(86.7142129)',
#  '58257',
#  '(56.6347972)',
#  '21196',
#  '(86.0186822)',
#  '19487',
#  '(87.2410374)',
#  '23172',
#  '(84.7756139)',
#  '31032',
#  '(79.3664875)',
#  '62714',
#  '(52.0169076)',
#  '40853',
#  '(72.1238249)',
#  '32862',
#  '(78.0626182)',
#  '22983',
#  '(84.7973150)',
#  '82209',
#  '(30.1146048)',
#  '38413',
#  '(73.8187976)',
#  '15892',
#  '(89.5517066)',
#  '89352',
#  '(20.0646488)',
#  '45518',
#  '(68.3243751)',
#  '24661',
#  '(83.6967382)',
#  'Stage',
#  '1',
#  'Cut Off Indicates All India Merit No.; Figures in bracket Indicates JEE(Main) Score/MHT-CET Percentile.; AI to AI-All India Seats Allotted to All India Candidature Candidates.',
#  'D',
#  'i',
#  'r',
#  'State Common Entrance Test Cell',
#  'Cut Off List of All India Seats CAP Round I for Admission to First Year of Four Year Full Time Degree Courses in Engineering and Technology for the Academic Year 2021-22',
#  'Government of Maharashtra',
#  '1002 - Government College of Engineering, Amravati',
#  '100237210 - Electronics and Telecommunication Engg',
#  'Status:',
#  'Government Autonomous',
#  'State Level',
#  'GOPENS',
#  'GSCS',
#  'GSTS',
#  'GVJS',
#  'GNT1S',
#  'GNT2S',
#  'GNT3S',
#  'GOBCS',
#  'LOPENS',
#  'LSCS',
#  'LSTS',
#  'LVJS',
#  'LNT1S',
#  'LNT2S',
#  'LOBCS',
#  'DEFOPENS',
#  'TFWS',
#  'DEFRSCS',
#  'EWS',
#  '  I',
#  '11873',
#  '(92.2042446)',
#  '22400',
#  '(85.2776363)',
#  '68170',
#  '(46.0655482)',
#  '23750',
#  '(84.4255069)',
#  '19500',
#  '(87.2410374)',
#  '14001',
#  '(90.7999591)',
#  '14878',
#  '(90.2037697)',
#  '13381',
#  '(91.1688967)',
#  '11592',
#  '(92.3906294)',
#  '18592',
#  '(87.8982812)',
#  '65264',
#  '(49.5849968)',
#  '48989',
#  '(65.5810044)',
#  '18397',
#  '(87.9403016)',
#  '39233',
#  '(72.9671324)',
#  '12636',
#  '(91.7347773)',
#  '31468',
#  '(79.0779419)',
#  '8906',
#  '(94.1228328)',
#  '63913',
#  '(51.2157744)',
#  '12824',
#  '(91.5780194)',
#  'Stage',
#  '100246610 - Instrumentation Engineering',
#  'Status:',
#  'Government Autonomous',
#  'State Level',
#  'GOPENS',
#  'GSCS',
#  'GVJS',
#  'GNT1S',
#  'GNT2S',
#  'GOBCS',
#  'LOPENS',
#  'LSCS',
#  'LOBCS',
#  'TFWS',
#  'EWS',
#  '  I',
#  '35736',
#  '(75.9153688)',
#  '46114',
#  '(67.8408129)',
#  '70900',
#  '(44.1945416)',
#  '83386',
#  '(27.4174428)',
#  '47051',
#  '(66.7554528)',
#  '42004',
#  '(70.8970412)',
#  '33732',
#  '(77.3804659)',
#  '41257',
#  '(71.5034873)',
#  '38019',
#  '(74.2881116)',
#  '27830',
#  '(81.6162428)',
#  '41599',
#  '(71.1205193)',
#  'Stage',
#  '100261210 - Mechanical Engineering',
#  'Status:',
#  'Government Autonomous',
#  'State Level',
#  'GOPENS',
#  'GSCS',
#  'GSTS',
#  'GVJS',
#  'GNT1S',
#  'GNT2S',
#  'GNT3S',
#  'GOBCS',
#  'LOPENS',
#  'LSCS',
#  'LSTS',
#  'LVJS',
#  'LNT1S',
#  'LNT2S',
#  'LOBCS',
#  'TFWS',
#  'EWS',
#  '  I',
#  '21324',
#  '(85.8629008)',
#  '33298',
#  '(77.6138784)',
#  '60169',
#  '(55.0214592)',
#  '33218',
#  '(77.7279132)',
#  '58862',
#  '(56.2588494)',
#  '27800',
#  '(81.6162428)',
#  '29310',
#  '(80.7066037)',
#  '23781',
#  '(84.4255069)',
#  '34253',
#  '(77.2185430)',
#  '39159',
#  '(73.3755778)',
#  '66488',
#  '(48.3716233)',
#  '74971',
#  '(38.5880670)',
#  '38673',
#  '(73.6463016)',
#  '78112',
#  '(34.2703923)',
#  '36518',
#  '(75.4365724)',
#  '17382',
#  '(88.5931753)',
#  '28658',
#  '(80.9163492)',
#  'Stage',
#  '1',
#  'Cut Off Indicates All India Merit No.; Figures in bracket Indicates JEE(Main) Score/MHT-CET Percentile.; AI to AI-All India Seats Allotted to All India Candidature Candidates.',
#  'D',
#  'i',
#  'r',
#  'State Common Entrance Test Cell',
#  'Cut Off List of All India Seats CAP Round I for Admission to First Year of Four Year Full Time Degree Courses in Engineering and Technology for the Academic Year 2021-22',
#  'Government of Maharashtra']

# %%
stages = [0, ]
for i, c in enumerate(college):
    if c == 'Stage':
        stages.append(i)
last_stage_course = stages[-1]

for j, _ in enumerate(stages):
    if _ != last_stage_course:
        course = college[stages[j+1]:stages[j]]

# %%
stages
# Out:
# [0, 66, 136, 206, 275, 347, 386, 443]

# %%
course = college[67:136]
course
# Out:
# ['100224210 - Computer Science and Engineering',
#  'Status:',
#  'Government Autonomous',
#  'State Level',
#  'GOPENS',
#  'GSCS',
#  'GSTS',
#  'GVJS',
#  'GNT1S',
#  'GNT2S',
#  'GNT3S',
#  'GOBCS',
#  'LOPENS',
#  'LSCS',
#  'LSTS',
#  'LVJS',
#  'LNT1S',
#  'LNT2S',
#  'LOBCS',
#  'PWDOPENS',
#  'DEFOPENS',
#  'TFWS',
#  'PWDROBC',
#  'S',
#  'DEFROBCS',
#  'EWS',
#  '  I',
#  '4731',
#  '(96.8328566)',
#  '8734',
#  '(94.2649898)',
#  '32517',
#  '(78.1762608)',
#  '16689',
#  '(89.0926089)',
#  '9216',
#  '(93.9671026)',
#  '5013',
#  '(96.6278018)',
#  '10315',
#  '(93.2254498)',
#  '5452',
#  '(96.3605852)',
#  '4280',
#  '(97.1143109)',
#  '13443',
#  '(91.1411105)',
#  '24468',
#  '(83.9803841)',
#  '13177',
#  '(91.3860690)',
#  '8590',
#  '(94.3333506)',
#  '15015',
#  '(90.1502416)',
#  '5729',
#  '(96.2010124)',
#  '27025',
#  '(82.1745519)',
#  '11104',
#  '(92.7475757)',
#  '3541',
#  '(97.5903614)',
#  '42953',
#  '(70.7140758)',
#  '23851',
#  '(84.2624154)',
#  '5378',
#  '(96.3865715)']

# %%
start = course.index('State Level') + 1
end = course.index('  I')

categories = course[start:end]
for i, category in enumerate(categories):
    if len(category) == 1:
        categories[i-1] += category
        del categories[i]
    
values = course[end+1:]

smls = [int(s) for s in values[::2] ]
cet_scores = [round(float(score[1:-1]), 2) for score in values[1::2]]

n = len(cet_scores)

c_code = [int(college_codes[0])] * n
c_name = [college_names[0]] * n
course_code = [course[0].split(' - ')[0]] * n
course_name = [course[0].split(' - ')[1]] * n
status = [course[course.index('Status:') + 1]] * n
genders = [g[0] for g in categories]
hos_types = ['S'] * n

# %%
df = pd.DataFrame({
    "College Code": c_code,
    "College Name": c_name,
    "Course Code": course_code,
    "Course Name": course_name,
    "Status": status,
    "Category": categories,
    "SML": smls,
    "CET Score": cet_scores,
    "Gender": genders,
    "H O S Type": hos_types
})

# %%
df
# Out:
#     College Code                                 College Name Course Code  \
# 0           1002  Government College of Engineering, Amravati   100224210
# 1           1002  Government College of Engineering, Amravati   100224210
# 2           1002  Government College of Engineering, Amravati   100224210
# 3           1002  Government College of Engineering, Amravati   100224210
# 4           1002  Government College of Engineering, Amravati   100224210
# 5           1002  Government College of Engineering, Amravati   100224210
# 6           1002  Government College of Engineering, Amravati   100224210
# 7           1002  Government College of Engineering, Amravati   100224210
# 8           1002  Government College of Engineering, Amravati   100224210
# 9           1002  Government College of Engineering, Amravati   100224210
# 10          1002  Government College of Engineering, Amravati   100224210
# 11          1002  Government College of Engineering, Amravati   100224210
# 12          1002  Government College of Engineering, Amravati   100224210
# 13          1002  Government College of Engineering, Amravati   100224210
# 14          1002  Government College of Engineering, Amravati   100224210
# 15          1002  Government College of Engineering, Amravati   100224210
# 16          1002  Government College of Engineering, Amravati   100224210
# 17          1002  Government College of Engineering, Amravati   100224210
# 18          1002  Government College of Engineering, Amravati   100224210
# 19          1002  Government College of Engineering, Amravati   100224210
# 20          1002  Government College of Engineering, Amravati   100224210
#
#                          Course Name                 Status  Category    SML  \
# 0   Computer Science and Engineering  Government Autonomous    GOPENS   4731
# 1   Computer Science and Engineering  Government Autonomous      GSCS   8734
# 2   Computer Science and Engineering  Government Autonomous      GSTS  32517
# 3   Computer Science and Engineering  Government Autonomous      GVJS  16689
# 4   Computer Science and Engineering  Government Autonomous     GNT1S   9216
# 5   Computer Science and Engineering  Government Autonomous     GNT2S   5013
# 6   Computer Science and Engineering  Government Autonomous     GNT3S  10315
# 7   Computer Science and Engineering  Government Autonomous     GOBCS   5452
# 8   Computer Science and Engineering  Government Autonomous    LOPENS   4280
# 9   Computer Science and Engineering  Government Autonomous      LSCS  13443
# 10  Computer Science and Engineering  Government Autonomous      LSTS  24468
# 11  Computer Science and Engineering  Government Autonomous      LVJS  13177
# 12  Computer Science and Engineering  Government Autonomous     LNT1S   8590
# 13  Computer Science and Engineering  Government Autonomous     LNT2S  15015
# 14  Computer Science and Engineering  Government Autonomous     LOBCS   5729
# 15  Computer Science and Engineering  Government Autonomous  PWDOPENS  27025
# 16  Computer Science and Engineering  Government Autonomous  DEFOPENS  11104
# 17  Computer Science and Engineering  Government Autonomous      TFWS   3541
# 18  Computer Science and Engineering  Government Autonomous  PWDROBCS  42953
# 19  Computer Science and Engineering  Government Autonomous  DEFROBCS  23851
# 20  Computer Science and Engineering  Government Autonomous       EWS   5378
#
#     CET Score Gender H O S Type
# 0       96.83      G          S
# 1       94.26      G          S
# 2       78.18      G          S
# 3       89.09      G          S
# 4       93.97      G          S
# 5       96.63      G          S
# 6       93.23      G          S
# 7       96.36      G          S
# 8       97.11      L          S
# 9       91.14      L          S
# 10      83.98      L          S
# 11      91.39      L          S
# 12      94.33      L          S
# 13      90.15      L          S
# 14      96.20      L          S
# 15      82.17      P          S
# 16      92.75      D          S
# 17      97.59      T          S
# 18      70.71      P          S
# 19      84.26      D          S
# 20      96.39      E          S

# %%
with fitz.open("FE_CAP Round_I_2021.pdf") as doc:
    text = ""
    for page in doc:
        text += page.get_text()

    lines = text.split("\n")
    college_indexes, college_codes, college_names = [], [], []

    for index, line in enumerate(lines):
        if ' - ' in line:
            code = line.split(" - ")[0].strip()
            college = line.split("-")[1].strip()
            if 'college' in college.lower() or 'university' in college.lower():
                if (len(code) == 4) and code.isdigit():
                    if (code not in college_codes):
                        college_indexes.append(index)
                        college_codes.append(code)
                        college_names.append(college)
    
    last_college_index = college_indexes[-1]
    for index, college_index in enumerate(college_indexes):
        college = lines[index:index+1] if college_index != last_college_index else lines[index:]
        stages = [0, ]
        for i, c in enumerate(college):
            if c == 'Stage':
                stages.append(i)

        for i, stage in enumerate(stages):
        course = college[stages[i]: stages[i+1]]

        start = course.index('State Level') + 1
        end = course.index('  I')

        headers = course[start:end]
        values = course[end+1:]

        smls = [int(s) for s in values[::2] ]
        cet_scores = [round(float(score[1:-1]), 2) for score in values[1::2]]

        n = len(cet_scores)

        c_code = [int(college_codes[0])] * n
        c_name = [college_names[0]] * n
        course_code = [course[0].split(' - ')[0]] * n
        course_name = [course[0].split(' - ')[1]] * n
        status = [course[2]] * n
        categories = headers
        genders = [g[0] for g in categories]
        hos_types = ['S'] * n

        df = pd.DataFrame({
            "College Code": c_code,
            "College Name": c_name,
            "Course Code": course_code,
            "Course Name": course_name,
            "Status": status,
            "Category": categories,
            "SML": smls,
            "CET Score": cet_scores,
            "Gender": genders,
            "H O S Type": hos_types
        })
